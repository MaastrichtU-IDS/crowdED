# %% [markdown]
# ## Workers Function
# ---

# %%
import sys
import pandas as pd
import numpy as np
import shortuuid as uid
from datetime import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Full Version 1.1

# %%
# ----------------------------------------- Crowdsourcing task optimization ----------------------------------------- 

# ### Tasks and Workers Dataframe Construction
def workers_algorithm(total_tasks = 100, total_workers = 40, p_hard_tasks = 0.2, p_good_workers = 0.8,
                      answers_key = ["liver", "blood", "lung", "brain", "heart"], 
                      p_train_tasks = 0.4, workers_per_task = 7):
    total_tasks =  total_tasks #int(input("Number of Total Tasks: "))  #100
    total_workers = total_workers #int(input("Number of Total Workers: "))  #40

    p_hard_tasks = float(p_hard_tasks) #float(input("Percentage of Hard Tasks (decimal): ")) # 0.2
    n_hard_tasks = int(round(p_hard_tasks*total_tasks,0))
    p_easy_tasks = 1-p_hard_tasks 
    n_easy_tasks = int(round(p_easy_tasks*total_tasks,0))
    print('Hard Tasks: {} \nEasy Tasks: {}'.format(n_hard_tasks, n_easy_tasks))

    #Workers variables
    p_good_workers = float(p_good_workers) #float(input("Percentage of Good Workers (decimal): ")) #0.8
    n_good_workers = int(round(p_good_workers*total_workers,0))
    p_poor_workers = 1-p_good_workers
    n_poor_workers = int(round(p_poor_workers*total_workers,0))
    print('Good Workers: {} \nPoor Workers: {}'.format(n_good_workers, n_poor_workers))

    # Workers simulation
    workers = [uid.ShortUUID().random(length=5) for i in range(total_workers)]
    poor_workers = [worker for worker in np.random.choice(workers, n_poor_workers, replace=False)]
    good_workers = [worker for worker in set(workers)-set(poor_workers)]

    # Creating the workers dataframe
    df_workers = pd.DataFrame()
    df_workers['worker_id'] = workers

    label_worker = []
    for i in range(total_workers):
        if workers[i] in good_workers:
            label_worker.append('good_worker')
        else:
            label_worker.append('poor_worker')

    df_workers['label_worker'] = label_worker

    # Tasks simulatiom
    tasks = ['task_'+uid.ShortUUID().random(length=3) for i in range(total_tasks)]
    easy_tasks = [task for task in np.random.choice(tasks, n_easy_tasks, replace=False)]
    hard_tasks = [task for task in set(tasks)-set(easy_tasks)]

    answers_key = ["liver", "blood", "lung", "brain", "heart"]
    #print('Tasks Answers: {}'.format(answers_key))
    real_answers = [answer for answer in np.random.choice(answers_key, total_tasks)]
    df_tasks = pd.DataFrame()
    df_tasks['task_id'] = tasks
    df_tasks['real_answers'] = real_answers

    label_task = []
    for i in range(total_tasks):
        if tasks[i] in hard_tasks:
            label_task.append('hard_task')
        else:
            label_task.append('easy_task')

    df_tasks['label_task'] = label_task


    # ----------------------------------------- Probability to Respond ----------------------------------------- 
    cut_tasks = 0.75
    cut_workers = 0.75

    probs_tasks = []
    for i in label_task:
        if i == 'easy_task':
            probs_tasks.append(np.random.choice((np.arange(cut_tasks, 1, 0.01)), 1)) #a random number form cut to 1
        elif i == 'hard_task':
            probs_tasks.append(np.random.choice((np.arange(0.5, cut_tasks, 0.01)), 1)) #a random number form chance to cut
        else: probs_tasks.append(1)

    probs_tasks = [item for prob in probs_tasks for item in prob]

    probs_workers = []
    for i in label_worker:
        if i == 'good_worker':
            probs_workers.append(np.random.choice((np.arange(cut_workers, 1, 0.01)), 1)) #a random number form cut to 1
        elif i == 'poor_worker':
            probs_workers.append(np.random.choice((np.arange(0.5, cut_workers, 0.01)), 1)) #a random number form chance to 1
        else: probs_workers.append(1)

    probs_workers = [item for prob in probs_workers for item in prob]

    df_workers['prob_worker'] = probs_workers
    df_tasks['prob_task'] = probs_tasks


    # ----------------------------------------- Stage 1 ----------------------------------------- 

    p_train_tasks = float(p_train_tasks) #float(input("Percentage of Tasks to Train (decimal): ")) #.4 #percentage
    #workers_per_task = 7 #more conditions

    tasks_to_train = int(p_train_tasks*total_tasks)
    print('Tasks to train: {}'.format(tasks_to_train))

    # Take randomly the number of tasks to train the workers
    training_tasks = np.random.choice(tasks, tasks_to_train, replace=False)

    list_tasks1 = [[training_tasks[i]]*workers_per_task for i in range(tasks_to_train)] #replicate the tasks to train 
    list_tasks1 = [item for sublist in list_tasks1 for item in sublist] #flat and clean list

    # Asign workers on every task (we're assuming the tasks are ordered)
    tasks_workers1 = [np.random.choice(workers, workers_per_task, replace=False) for task in training_tasks]
    tasks_workers1 = [worker for sublist in tasks_workers1 for worker in sublist] #flat and clean list

    temp_frame = pd.DataFrame()
    temp_frame['task_id'] = list_tasks1
    temp_frame['worker_id'] = tasks_workers1

    workers_agg = temp_frame.groupby('worker_id').agg('count')
    workers_agg.sort_values('task_id', ascending=False)
    num_workers_trained = len(workers_agg.reset_index())
    print('Workers Trained: {}'.format(num_workers_trained))

    # Merge the datasets stage 1
    temp_frame1 = pd.merge(temp_frame, df_tasks, on='task_id', how='left')
    df_tw1 = pd.merge(temp_frame1, df_workers, on='worker_id', how='left')

    #Probability to asnwer correct
    df_tw1['prob_answer'] = 1-(df_tw1['prob_worker']*(1-df_tw1['prob_task']))

    # We want to get where is the position of the real_answer column on the answer_key array
    positions = []
    for answer in df_tw1['real_answers']:
        for k in range(len(answers_key)):
            if answers_key[k] == answer:
                positions.append(k)

    # Assign a vector of probabilities depending on the position of the item on anser_key array
    list_vect_probs = []
    for p in df_tw1['prob_answer']:
        for i in positions:
            vec_probs = [(1-p)/(len(answers_key)-1)] * (len(answers_key)-1)
            vec_probs.insert(i,p) #insert place, value
        list_vect_probs.append(vec_probs)

    #"Predict" every answer
    worker_answers = []
    for vec in list_vect_probs:
        worker_answers.append(np.random.choice(answers_key, 1, p=vec))

    worker_answers = [item for answer in worker_answers for item in answer]
    df_tw1['worker_answers'] = worker_answers

    #We match the real answers with worker answers
    vec_matches = df_tw1['worker_answers'] == df_tw1['real_answers']
    predict_value =[1 if i == True else 0 for i in vec_matches]
    df_tw1['performance'] = predict_value

    # ----------------------------------------- Measuring Performance ----------------------------------------- 

    cutoff_task = 0.5 #More than 50% of consensus

    tasks_mean1 = df_tw1.groupby('task_id').mean().sort_values('performance', ascending=False)
    first_tasks = tasks_mean1[tasks_mean1['performance'] >= cutoff_task]['performance']

    # - Trained Workers
    workers_mean1 = df_tw1.groupby('worker_id').mean().sort_values('performance', ascending=False)
    df_workers = pd.merge(workers_mean1.reset_index(), df_workers.drop('prob_worker',1), on='worker_id', how='left')

    # - prob_task: Average of difficulty of the tasks asigned to the workers, this measure should be close each other in order to make the metrics equivalent
    # - prob_worker: Prob to score correct
    # - prob_answer: Combined probability of score and task difficulty
    # - performance: Percentage of the times the worker score correct

    #print('Workers Performance Summary: \n{}'.format(df_workers.describe()))

    cutoff1 = df_workers['performance'].quantile(.3)
    cutoff2 = df_workers['prob_worker'].quantile(.5)
    print('Cutoff for Performance: {} \nCutoff for Probability: {}'.format(
        round(cutoff1, 3), round(cutoff2, 3)))

    # ----------------------------------------- Stage 2 - Best workers ----------------------------------------- 

    # We are going take only the best workers, it means high probability and high performance, above certain percentile. 
    list_perf = [1 if i > cutoff1 else 0 for i in df_workers['performance']]
    list_prob = [1 if i > cutoff2 else 0 for i in df_workers['prob_worker']]

    flag_best_workers = []
    for i in range(len(list_perf)):
        if list_perf[i] == 1 and list_prob[i] ==1 : #we need to be strict here
            flag_best_workers.append(1)
        else: flag_best_workers.append(0)

    print('Selected Best Workers: {}'.format(sum(flag_best_workers)))

    df_workers['best_worker'] = flag_best_workers
    df_workers2 = df_workers[df_workers['best_worker']==1]
    # But we want to "reset" them:
    df_workers2 = df_workers2[['worker_id','prob_worker','label_worker']]
    best_workers = [i for i in df_workers2['worker_id']]

    # - Now we take the tasks that we decide were already difficult
    # - Then we're going to add them in the df_tasks that we did not use
    # - This "rest" of the tasks remain are going to be performed for our final workers
    tasks_mean1 = tasks_mean1.reset_index()
    list_done_tasks = [1 if i > cutoff_task else 0 for i in tasks_mean1['performance']]
    tasks_mean1['done_task'] = list_done_tasks
    #All those with value 1 is because was good consensus, so we don't need them to evaluate again
    tasks_mean1[tasks_mean1['done_task']==1]
    done_tasks = tasks_mean1[tasks_mean1['done_task']==1]['task_id']
    done_tasks = [i for i in done_tasks]
    # - Those trained_task with value 1 don't select them
    # - The best workers will do the rest of the job
    # - Then we measure the accuracy of the over tasks and workers
    # - Simulations and ploting the acuracy and the best workers, 
    # - Ploting workers converge on truth answer
    print('Tasks already done {} from the total of {}'.format(len(done_tasks), len(df_tasks)))
    # Take all the rest of the tasks excluding those that already we have concensus
    # This is the number we want to evaluate in stage 2
    df_tasks2 = df_tasks[~df_tasks['task_id'].isin(done_tasks)]
    #print('Tasks to be done: {}'.format(len(df_tasks2)))

    # ----------------------------------------- Stage 2 - Task Assignation ----------------------------------------- 
    # Before we assigne the best workers to the rest of the tasks we have to be sure that the workers dont responde the same task
    # All the tasks done for the best workers and is not in the list of tasks already done
    tasks_redo = df_tw1[~df_tw1['task_id'].isin(done_tasks)]
    tasks_redo = tasks_redo.reset_index()
    tasks_redo_unique = tasks_redo['task_id'].unique()
    tasks_redo_unique =  [i for i in tasks_redo_unique]

    # ** Check Groups: ** All the trained and consensus tasks + All the tasks already done = Trained Tasks
    #print(' Done Taks: {} \n Tasks to redo: {} \n Original Tasks to train: {}  \n Value: {}'.format(
    #    len(done_tasks), len(tasks_redo_unique), tasks_to_train, len(done_tasks)+len(tasks_redo_unique)==tasks_to_train))

    tasks_workers2 = [] #we should take in account that there is a low chance that the worker repat the task
    for i in tasks_redo_unique:
        each = [i for i in tasks_redo[tasks_redo['task_id']==str(i)]['worker_id']] # show the worker id of every task
        rest_workers = [worker for worker in set(best_workers)-set(each)] # select all those not did the task before
        if len(rest_workers) > workers_per_task:
            tasks_workers2.append(np.random.choice(rest_workers, workers_per_task, replace=False))
        else:
            tasks_workers2.append(np.random.choice(rest_workers, workers_per_task))

    tasks_workers2 = [worker for sublist in tasks_workers2 for worker in sublist] #flat and clean list

    list_tasks2 = [[tasks_redo_unique[i]]*workers_per_task for i in range(len(tasks_redo_unique))] #replicate the tasks to train 
    list_tasks2 = [item for sublist in list_tasks2 for item in sublist] #flat and clean list

    temp_frame1 = pd.DataFrame()
    temp_frame1['task_id'] = list_tasks2
    temp_frame1['worker_id'] = tasks_workers2
    # - **Tasks Un-done**
    tasks_undone_unique = df_tasks[~df_tasks['task_id'].isin(training_tasks)]['task_id']
    tasks_undone_unique = [i for i in tasks_undone_unique]
    # ** Check Groups: ** Tasks re-do unique + Tasks un-done unique = df_tasks2 
    #print('Final Stage\n Tasks Re-do: {} \n Tasks Not Done: {}'.format(
    #    len(tasks_redo_unique) , len(tasks_undone_unique)))

    tasks_workers3 = []
    for i in tasks_undone_unique:
        tasks_workers3.append(np.random.choice(best_workers, workers_per_task, replace=False))

    tasks_workers3 = [worker for sublist in tasks_workers3 for worker in sublist] #flat and clean list

    list_tasks3 = [[tasks_undone_unique[i]]*workers_per_task for i in range(len(tasks_undone_unique))] #replicate the tasks to train 
    list_tasks3 = [item for sublist in list_tasks3 for item in sublist] #flat and clean list

    temp_frame2 = pd.DataFrame()
    temp_frame2['task_id'] = list_tasks3
    temp_frame2['worker_id'] = tasks_workers3

    # ----------------------------------------- Final Join ----------------------------------------- 

    temp_frame = temp_frame1.append(temp_frame2, ignore_index=True)
    #print('Number of Tasks in Final Join: {}'.format(len(temp_frame['task_id'].unique())))

    temp_frame0 = pd.merge(temp_frame, df_tasks2, on='task_id', how='left')
    df_tw = pd.merge(temp_frame0, df_workers2, on='worker_id', how='left')

    #Probability to asnwer correct
    df_tw['prob_answer'] = 1-(df_tw['prob_worker']*(1-df_tw['prob_task']))

    # We want to get where is the position of the real_answer column on the answer_key array
    positions = []
    for answer in df_tw['real_answers']:
        for k in range(len(answers_key)):
            if answers_key[k] == answer:
                positions.append(k)

    # Assign a vector of probabilities depending on the position of the item on anser_key array
    list_vect_probs = []
    for p in df_tw['prob_answer']:
        for i in positions:
            vec_probs = [(1-p)/(len(answers_key)-1)] * (len(answers_key)-1)
            vec_probs.insert(i,p) #insert place, value
        list_vect_probs.append(vec_probs)

    #"Predict" every answer
    worker_answers = []
    for vec in list_vect_probs:
        worker_answers.append(np.random.choice(answers_key, 1, p=vec))

    worker_answers = [item for answer in worker_answers for item in answer]
    df_tw['worker_answers'] = worker_answers
    #We match the real answers with worker answers
    vec_matches = df_tw['worker_answers'] == df_tw['real_answers']
    predict_value =[1 if i == True else 0 for i in vec_matches]
    df_tw['performance'] = predict_value

    # ----------------------------------------- Accuracy ----------------------------------------- 

    tasks_mean = df_tw.groupby('task_id').mean().sort_values('performance', ascending=False)
    final_tasks = tasks_mean[tasks_mean['performance'] >= cutoff_task]['performance']

    #print('\n \n ==== Agreement on the Tasks ==== \n \n')

    #print(first_tasks.append(final_tasks).sort_values(ascending=False))

    print('Task consensus: {} of {}'.format(len(final_tasks) + len(done_tasks), len(df_tasks)))

    accu = (len(first_tasks) + len(final_tasks)) / len(df_tasks)

    print('Accuracy Simulation: {} \n============================'.format(accu))
    
    return accu

# %% [markdown]
# ## Predefined Parameters
# ---

# %%
workers_algorithm()
# Out:
# Hard Tasks: 20
# Easy Tasks: 80
# Good Workers: 32
# Poor Workers: 8
# Tasks to train: 40
# Workers Trained: 40
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.82
# Selected Best Workers: 13
# Tasks already done 10 from the total of 100
# Task consensus: 29 of 100
# Accuracy Simulation: 0.29
# ============================
# 0.29

# %%
accu_1 = workers_algorithm(total_tasks = 1000, total_workers = 50, p_hard_tasks = 0.1, p_good_workers = 0.9,
                           answers_key = ["liver", "blood", "lung", "brain", "heart"], 
                           p_train_tasks = 0.5, workers_per_task = 7)
# Out:
# Hard Tasks: 100
# Easy Tasks: 900
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 500
# Workers Trained: 50
# Cutoff for Performance: 0.176
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 102 from the total of 1000
# Task consensus: 303 of 1000
# Accuracy Simulation: 0.303
# ============================

# %%
accu_1
# Out:
# 0.303

# %% [markdown]
# ---
# ## Change the number tasks, Fixed all the rest variables

# %%
def train_parameter(max_value):
    results = []
    for idx, i in enumerate(np.arange(1, max_value, 1)):
        try:
            results.append((idx,
                           workers_algorithm(total_tasks = i + 1, #(0,1000)
                                             total_workers = 50, #(0,1000)
                                             p_hard_tasks = 0.1, #(0,1)
                                             p_good_workers = 0.9, #(0,1)
                                             p_train_tasks = 0.5, #(0,1)
                                             workers_per_task = 7))) #3,5,7,9,11,13,15
        except Exception:
            pass
    return results

# %%
results = train_parameter(200)
# Out:
# Hard Tasks: 0
# Easy Tasks: 2
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 1
# Workers Trained: 7
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.8
# Selected Best Workers: 0
# Tasks already done 1 from the total of 2
# Hard Tasks: 0
# Easy Tasks: 3
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 1
# Workers Trained: 7
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.75
# Selected Best Workers: 0
# Tasks already done 1 from the total of 3
# Hard Tasks: 0
# Easy Tasks: 4
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 2
# Workers Trained: 14
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.895
# Selected Best Workers: 0
# Tasks already done 2 from the total of 4
# Hard Tasks: 0
# Easy Tasks: 4
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 2
# Workers Trained: 14
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.845
# Selected Best Workers: 5
# Tasks already done 1 from the total of 5
# Hard Tasks: 1
# Easy Tasks: 5
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 3
# Workers Trained: 18
# Cutoff for Performance: 0.5
# Cutoff for Probability: 0.905
# Selected Best Workers: 5
# Tasks already done 2 from the total of 6
# Hard Tasks: 1
# Easy Tasks: 6
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 3
# Workers Trained: 19
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 1
# Tasks already done 1 from the total of 7
# Hard Tasks: 1
# Easy Tasks: 7
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 4
# Workers Trained: 24
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 3
# Tasks already done 1 from the total of 8
# Hard Tasks: 1
# Easy Tasks: 8
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 4
# Workers Trained: 25
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.81
# Selected Best Workers: 6
# Tasks already done 2 from the total of 9
# Hard Tasks: 1
# Easy Tasks: 9
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 5
# Workers Trained: 26
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 5
# Tasks already done 2 from the total of 10
# Hard Tasks: 1
# Easy Tasks: 10
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 5
# Workers Trained: 27
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.91
# Selected Best Workers: 5
# Tasks already done 2 from the total of 11
# Hard Tasks: 1
# Easy Tasks: 11
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 6
# Workers Trained: 29
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.82
# Selected Best Workers: 8
# Tasks already done 3 from the total of 12
# Task consensus: 5 of 12
# Accuracy Simulation: 0.4166666666666667
# ============================
# Hard Tasks: 1
# Easy Tasks: 12
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 6
# Workers Trained: 29
# Cutoff for Performance: 0.8
# Cutoff for Probability: 0.84
# Selected Best Workers: 9
# Tasks already done 5 from the total of 13
# Task consensus: 8 of 13
# Accuracy Simulation: 0.6153846153846154
# ============================
# Hard Tasks: 1
# Easy Tasks: 13
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 7
# Workers Trained: 32
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.875
# Selected Best Workers: 5
# Tasks already done 1 from the total of 14
# Hard Tasks: 2
# Easy Tasks: 14
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 7
# Workers Trained: 31
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.89
# Selected Best Workers: 4
# Tasks already done 1 from the total of 15
# Hard Tasks: 2
# Easy Tasks: 14
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 8
# Workers Trained: 35
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.81
# Selected Best Workers: 12
# Tasks already done 4 from the total of 16
# Task consensus: 10 of 16
# Accuracy Simulation: 0.625
# ============================
# Hard Tasks: 2
# Easy Tasks: 15
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 8
# Workers Trained: 35
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 5
# Tasks already done 2 from the total of 17
# Hard Tasks: 2
# Easy Tasks: 16
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 9
# Workers Trained: 36
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 9
# Tasks already done 3 from the total of 18
# Task consensus: 9 of 18
# Accuracy Simulation: 0.5
# ============================
# Hard Tasks: 2
# Easy Tasks: 17
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 9
# Workers Trained: 32
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 9
# Tasks already done 2 from the total of 19
# Task consensus: 7 of 19
# Accuracy Simulation: 0.3684210526315789
# ============================
# Hard Tasks: 2
# Easy Tasks: 18
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 10
# Workers Trained: 38
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 13
# Tasks already done 5 from the total of 20
# Task consensus: 9 of 20
# Accuracy Simulation: 0.45
# ============================
# Hard Tasks: 2
# Easy Tasks: 19
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 10
# Workers Trained: 39
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 7
# Tasks already done 2 from the total of 21
# Task consensus: 7 of 21
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 2
# Easy Tasks: 20
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 11
# Workers Trained: 41
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 5
# Tasks already done 2 from the total of 22
# Hard Tasks: 2
# Easy Tasks: 21
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 11
# Workers Trained: 41
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 11
# Tasks already done 5 from the total of 23
# Task consensus: 10 of 23
# Accuracy Simulation: 0.43478260869565216
# ============================
# Hard Tasks: 2
# Easy Tasks: 22
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 12
# Workers Trained: 40
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 3
# Tasks already done 2 from the total of 24
# Hard Tasks: 2
# Easy Tasks: 22
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 12
# Workers Trained: 43
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 13
# Tasks already done 7 from the total of 25
# Task consensus: 12 of 25
# Accuracy Simulation: 0.48
# ============================
# Hard Tasks: 3
# Easy Tasks: 23
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 13
# Workers Trained: 43
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 8
# Tasks already done 3 from the total of 26
# Task consensus: 6 of 26
# Accuracy Simulation: 0.23076923076923078
# ============================
# Hard Tasks: 3
# Easy Tasks: 24
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 13
# Workers Trained: 44
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 6
# Tasks already done 1 from the total of 27
# Hard Tasks: 3
# Easy Tasks: 25
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 14
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 11
# Tasks already done 5 from the total of 28
# Task consensus: 11 of 28
# Accuracy Simulation: 0.39285714285714285
# ============================
# Hard Tasks: 3
# Easy Tasks: 26
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 14
# Workers Trained: 46
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 6
# Tasks already done 4 from the total of 29
# Hard Tasks: 3
# Easy Tasks: 27
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 15
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 11
# Tasks already done 6 from the total of 30
# Task consensus: 12 of 30
# Accuracy Simulation: 0.4
# ============================
# Hard Tasks: 3
# Easy Tasks: 28
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 15
# Workers Trained: 45
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 7
# Tasks already done 2 from the total of 31
# Task consensus: 16 of 31
# Accuracy Simulation: 0.5161290322580645
# ============================
# Hard Tasks: 3
# Easy Tasks: 29
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 16
# Workers Trained: 42
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 6
# Tasks already done 2 from the total of 32
# Hard Tasks: 3
# Easy Tasks: 30
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 16
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 10
# Tasks already done 2 from the total of 33
# Task consensus: 6 of 33
# Accuracy Simulation: 0.18181818181818182
# ============================
# Hard Tasks: 3
# Easy Tasks: 31
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 17
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 13
# Tasks already done 6 from the total of 34
# Task consensus: 16 of 34
# Accuracy Simulation: 0.47058823529411764
# ============================
# Hard Tasks: 4
# Easy Tasks: 32
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 17
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 7
# Tasks already done 3 from the total of 35
# Task consensus: 10 of 35
# Accuracy Simulation: 0.2857142857142857
# ============================
# Hard Tasks: 4
# Easy Tasks: 32
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 18
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 13
# Tasks already done 7 from the total of 36
# Task consensus: 10 of 36
# Accuracy Simulation: 0.2777777777777778
# ============================
# Hard Tasks: 4
# Easy Tasks: 33
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 18
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.845
# Selected Best Workers: 17
# Tasks already done 6 from the total of 37
# Task consensus: 11 of 37
# Accuracy Simulation: 0.2972972972972973
# ============================
# Hard Tasks: 4
# Easy Tasks: 34
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 19
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 6 from the total of 38
# Task consensus: 10 of 38
# Accuracy Simulation: 0.2631578947368421
# ============================
# Hard Tasks: 4
# Easy Tasks: 35
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 19
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 16
# Tasks already done 6 from the total of 39
# Task consensus: 13 of 39
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 4
# Easy Tasks: 36
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 20
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 11
# Tasks already done 4 from the total of 40
# Task consensus: 10 of 40
# Accuracy Simulation: 0.25
# ============================
# Hard Tasks: 4
# Easy Tasks: 37
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 20
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 8
# Tasks already done 4 from the total of 41
# Task consensus: 16 of 41
# Accuracy Simulation: 0.3902439024390244
# ============================
# Hard Tasks: 4
# Easy Tasks: 38
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 21
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 13
# Tasks already done 6 from the total of 42
# Task consensus: 15 of 42
# Accuracy Simulation: 0.35714285714285715
# ============================
# Hard Tasks: 4
# Easy Tasks: 39
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 21
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 6
# Tasks already done 2 from the total of 43
# Hard Tasks: 4
# Easy Tasks: 40
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 22
# Workers Trained: 49
# Cutoff for Performance: 0.25
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 10 from the total of 44
# Task consensus: 19 of 44
# Accuracy Simulation: 0.4318181818181818
# ============================
# Hard Tasks: 4
# Easy Tasks: 40
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 22
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 9
# Tasks already done 7 from the total of 45
# Task consensus: 16 of 45
# Accuracy Simulation: 0.35555555555555557
# ============================
# Hard Tasks: 5
# Easy Tasks: 41
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 23
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 13
# Tasks already done 5 from the total of 46
# Task consensus: 14 of 46
# Accuracy Simulation: 0.30434782608695654
# ============================
# Hard Tasks: 5
# Easy Tasks: 42
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 23
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 11
# Tasks already done 3 from the total of 47
# Task consensus: 11 of 47
# Accuracy Simulation: 0.23404255319148937
# ============================
# Hard Tasks: 5
# Easy Tasks: 43
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 24
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.835
# Selected Best Workers: 14
# Tasks already done 6 from the total of 48
# Task consensus: 16 of 48
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 5
# Easy Tasks: 44
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 24
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 5 from the total of 49
# Task consensus: 21 of 49
# Accuracy Simulation: 0.42857142857142855
# ============================
# Hard Tasks: 5
# Easy Tasks: 45
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 25
# Workers Trained: 49
# Cutoff for Performance: 0.067
# Cutoff for Probability: 0.86
# Selected Best Workers: 19
# Tasks already done 9 from the total of 50
# Task consensus: 17 of 50
# Accuracy Simulation: 0.34
# ============================
# Hard Tasks: 5
# Easy Tasks: 46
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 25
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 6 from the total of 51
# Task consensus: 16 of 51
# Accuracy Simulation: 0.3137254901960784
# ============================
# Hard Tasks: 5
# Easy Tasks: 47
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 26
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 14
# Tasks already done 6 from the total of 52
# Task consensus: 17 of 52
# Accuracy Simulation: 0.3269230769230769
# ============================
# Hard Tasks: 5
# Easy Tasks: 48
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 26
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 6 from the total of 53
# Task consensus: 15 of 53
# Accuracy Simulation: 0.2830188679245283
# ============================
# Hard Tasks: 5
# Easy Tasks: 49
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 27
# Workers Trained: 48
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.845
# Selected Best Workers: 16
# Tasks already done 10 from the total of 54
# Task consensus: 21 of 54
# Accuracy Simulation: 0.3888888888888889
# ============================
# Hard Tasks: 6
# Easy Tasks: 50
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 27
# Workers Trained: 49
# Cutoff for Performance: 0.155
# Cutoff for Probability: 0.89
# Selected Best Workers: 16
# Tasks already done 8 from the total of 55
# Task consensus: 20 of 55
# Accuracy Simulation: 0.36363636363636365
# ============================
# Hard Tasks: 6
# Easy Tasks: 50
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 28
# Workers Trained: 48
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 7 from the total of 56
# Task consensus: 21 of 56
# Accuracy Simulation: 0.375
# ============================
# Hard Tasks: 6
# Easy Tasks: 51
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 28
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 7 from the total of 57
# Task consensus: 16 of 57
# Accuracy Simulation: 0.2807017543859649
# ============================
# Hard Tasks: 6
# Easy Tasks: 52
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 29
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 13
# Tasks already done 5 from the total of 58
# Task consensus: 18 of 58
# Accuracy Simulation: 0.3103448275862069
# ============================
# Hard Tasks: 6
# Easy Tasks: 53
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 29
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 6 from the total of 59
# Task consensus: 22 of 59
# Accuracy Simulation: 0.3728813559322034
# ============================
# Hard Tasks: 6
# Easy Tasks: 54
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 30
# Workers Trained: 49
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 8 from the total of 60
# Task consensus: 19 of 60
# Accuracy Simulation: 0.31666666666666665
# ============================
# Hard Tasks: 6
# Easy Tasks: 55
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 30
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.9
# Selected Best Workers: 16
# Tasks already done 4 from the total of 61
# Task consensus: 20 of 61
# Accuracy Simulation: 0.32786885245901637
# ============================
# Hard Tasks: 6
# Easy Tasks: 56
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 31
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 14
# Tasks already done 3 from the total of 62
# Task consensus: 20 of 62
# Accuracy Simulation: 0.3225806451612903
# ============================
# Hard Tasks: 6
# Easy Tasks: 57
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 31
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 15
# Tasks already done 8 from the total of 63
# Task consensus: 18 of 63
# Accuracy Simulation: 0.2857142857142857
# ============================
# Hard Tasks: 6
# Easy Tasks: 58
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 32
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 13
# Tasks already done 7 from the total of 64
# Task consensus: 21 of 64
# Accuracy Simulation: 0.328125
# ============================
# Hard Tasks: 6
# Easy Tasks: 58
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 32
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 6 from the total of 65
# Task consensus: 16 of 65
# Accuracy Simulation: 0.24615384615384617
# ============================
# Hard Tasks: 7
# Easy Tasks: 59
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 33
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.835
# Selected Best Workers: 19
# Tasks already done 7 from the total of 66
# Task consensus: 11 of 66
# Accuracy Simulation: 0.16666666666666666
# ============================
# Hard Tasks: 7
# Easy Tasks: 60
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 33
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 10 from the total of 67
# Task consensus: 22 of 67
# Accuracy Simulation: 0.3283582089552239
# ============================
# Hard Tasks: 7
# Easy Tasks: 61
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 34
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 6 from the total of 68
# Task consensus: 21 of 68
# Accuracy Simulation: 0.3088235294117647
# ============================
# Hard Tasks: 7
# Easy Tasks: 62
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 34
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 14
# Tasks already done 6 from the total of 69
# Task consensus: 17 of 69
# Accuracy Simulation: 0.2463768115942029
# ============================
# Hard Tasks: 7
# Easy Tasks: 63
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 35
# Workers Trained: 49
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.83
# Selected Best Workers: 16
# Tasks already done 9 from the total of 70
# Task consensus: 26 of 70
# Accuracy Simulation: 0.37142857142857144
# ============================
# Hard Tasks: 7
# Easy Tasks: 64
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 35
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.89
# Selected Best Workers: 9
# Tasks already done 3 from the total of 71
# Task consensus: 15 of 71
# Accuracy Simulation: 0.2112676056338028
# ============================
# Hard Tasks: 7
# Easy Tasks: 65
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 36
# Workers Trained: 50
# Cutoff for Performance: 0.07
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 8 from the total of 72
# Task consensus: 26 of 72
# Accuracy Simulation: 0.3611111111111111
# ============================
# Hard Tasks: 7
# Easy Tasks: 66
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 36
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 13
# Tasks already done 4 from the total of 73
# Task consensus: 10 of 73
# Accuracy Simulation: 0.136986301369863
# ============================
# Hard Tasks: 7
# Easy Tasks: 67
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 37
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 14
# Tasks already done 7 from the total of 74
# Task consensus: 27 of 74
# Accuracy Simulation: 0.36486486486486486
# ============================
# Hard Tasks: 8
# Easy Tasks: 68
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 37
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 8 from the total of 75
# Task consensus: 20 of 75
# Accuracy Simulation: 0.26666666666666666
# ============================
# Hard Tasks: 8
# Easy Tasks: 68
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 38
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.835
# Selected Best Workers: 15
# Tasks already done 13 from the total of 76
# Task consensus: 22 of 76
# Accuracy Simulation: 0.2894736842105263
# ============================
# Hard Tasks: 8
# Easy Tasks: 69
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 38
# Workers Trained: 50
# Cutoff for Performance: 0.07
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 7 from the total of 77
# Task consensus: 17 of 77
# Accuracy Simulation: 0.22077922077922077
# ============================
# Hard Tasks: 8
# Easy Tasks: 70
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 39
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 9
# Tasks already done 4 from the total of 78
# Task consensus: 14 of 78
# Accuracy Simulation: 0.1794871794871795
# ============================
# Hard Tasks: 8
# Easy Tasks: 71
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 39
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 13
# Tasks already done 4 from the total of 79
# Task consensus: 24 of 79
# Accuracy Simulation: 0.3037974683544304
# ============================
# Hard Tasks: 8
# Easy Tasks: 72
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 40
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.89
# Selected Best Workers: 18
# Tasks already done 10 from the total of 80
# Task consensus: 29 of 80
# Accuracy Simulation: 0.3625
# ============================
# Hard Tasks: 8
# Easy Tasks: 73
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 40
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 11 from the total of 81
# Task consensus: 30 of 81
# Accuracy Simulation: 0.37037037037037035
# ============================
# Hard Tasks: 8
# Easy Tasks: 74
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 41
# Workers Trained: 50
# Cutoff for Performance: 0.275
# Cutoff for Probability: 0.87
# Selected Best Workers: 15
# Tasks already done 13 from the total of 82
# Task consensus: 16 of 82
# Accuracy Simulation: 0.1951219512195122
# ============================
# Hard Tasks: 8
# Easy Tasks: 75
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 41
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.845
# Selected Best Workers: 17
# Tasks already done 8 from the total of 83
# Task consensus: 25 of 83
# Accuracy Simulation: 0.30120481927710846
# ============================
# Hard Tasks: 8
# Easy Tasks: 76
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 42
# Workers Trained: 50
# Cutoff for Performance: 0.087
# Cutoff for Probability: 0.84
# Selected Best Workers: 19
# Tasks already done 9 from the total of 84
# Task consensus: 22 of 84
# Accuracy Simulation: 0.2619047619047619
# ============================
# Hard Tasks: 8
# Easy Tasks: 76
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 42
# Workers Trained: 50
# Cutoff for Performance: 0.137
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 10 from the total of 85
# Task consensus: 29 of 85
# Accuracy Simulation: 0.3411764705882353
# ============================
# Hard Tasks: 9
# Easy Tasks: 77
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 43
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.855
# Selected Best Workers: 18
# Tasks already done 9 from the total of 86
# Task consensus: 31 of 86
# Accuracy Simulation: 0.36046511627906974
# ============================
# Hard Tasks: 9
# Easy Tasks: 78
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 43
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 5 from the total of 87
# Task consensus: 34 of 87
# Accuracy Simulation: 0.39080459770114945
# ============================
# Hard Tasks: 9
# Easy Tasks: 79
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 44
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.885
# Selected Best Workers: 14
# Tasks already done 11 from the total of 88
# Task consensus: 26 of 88
# Accuracy Simulation: 0.29545454545454547
# ============================
# Hard Tasks: 9
# Easy Tasks: 80
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 44
# Workers Trained: 49
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.9
# Selected Best Workers: 15
# Tasks already done 10 from the total of 89
# Task consensus: 25 of 89
# Accuracy Simulation: 0.2808988764044944
# ============================
# Hard Tasks: 9
# Easy Tasks: 81
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 45
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.89
# Selected Best Workers: 8
# Tasks already done 4 from the total of 90
# Task consensus: 28 of 90
# Accuracy Simulation: 0.3111111111111111
# ============================
# Hard Tasks: 9
# Easy Tasks: 82
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 45
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.855
# Selected Best Workers: 21
# Tasks already done 11 from the total of 91
# Task consensus: 25 of 91
# Accuracy Simulation: 0.27472527472527475
# ============================
# Hard Tasks: 9
# Easy Tasks: 83
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 46
# Workers Trained: 49
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 12 from the total of 92
# Task consensus: 24 of 92
# Accuracy Simulation: 0.2608695652173913
# ============================
# Hard Tasks: 9
# Easy Tasks: 84
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 46
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.875
# Selected Best Workers: 17
# Tasks already done 6 from the total of 93
# Task consensus: 14 of 93
# Accuracy Simulation: 0.15053763440860216
# ============================
# Hard Tasks: 9
# Easy Tasks: 85
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 47
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.845
# Selected Best Workers: 17
# Tasks already done 8 from the total of 94
# Task consensus: 34 of 94
# Accuracy Simulation: 0.3617021276595745
# ============================
# Hard Tasks: 10
# Easy Tasks: 86
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 47
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 16
# Tasks already done 7 from the total of 95
# Task consensus: 23 of 95
# Accuracy Simulation: 0.24210526315789474
# ============================
# Hard Tasks: 10
# Easy Tasks: 86
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 48
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 7 from the total of 96
# Task consensus: 14 of 96
# Accuracy Simulation: 0.14583333333333334
# ============================
# Hard Tasks: 10
# Easy Tasks: 87
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 48
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 10 from the total of 97
# Task consensus: 25 of 97
# Accuracy Simulation: 0.25773195876288657
# ============================
# Hard Tasks: 10
# Easy Tasks: 88
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 49
# Workers Trained: 50
# Cutoff for Performance: 0.25
# Cutoff for Probability: 0.83
# Selected Best Workers: 14
# Tasks already done 16 from the total of 98
# Task consensus: 29 of 98
# Accuracy Simulation: 0.29591836734693877
# ============================
# Hard Tasks: 10
# Easy Tasks: 89
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 49
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.855
# Selected Best Workers: 14
# Tasks already done 11 from the total of 99
# Task consensus: 28 of 99
# Accuracy Simulation: 0.2828282828282828
# ============================
# Hard Tasks: 10
# Easy Tasks: 90
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 50
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 8
# Tasks already done 4 from the total of 100
# Task consensus: 23 of 100
# Accuracy Simulation: 0.23
# ============================
# Hard Tasks: 10
# Easy Tasks: 91
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 50
# Workers Trained: 50
# Cutoff for Performance: 0.177
# Cutoff for Probability: 0.83
# Selected Best Workers: 19
# Tasks already done 15 from the total of 101
# Task consensus: 37 of 101
# Accuracy Simulation: 0.36633663366336633
# ============================
# Hard Tasks: 10
# Easy Tasks: 92
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 51
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.825
# Selected Best Workers: 16
# Tasks already done 7 from the total of 102
# Task consensus: 23 of 102
# Accuracy Simulation: 0.22549019607843138
# ============================
# Hard Tasks: 10
# Easy Tasks: 93
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 51
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.865
# Selected Best Workers: 19
# Tasks already done 8 from the total of 103
# Task consensus: 30 of 103
# Accuracy Simulation: 0.2912621359223301
# ============================
# Hard Tasks: 10
# Easy Tasks: 94
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 52
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.89
# Selected Best Workers: 16
# Tasks already done 13 from the total of 104
# Task consensus: 36 of 104
# Accuracy Simulation: 0.34615384615384615
# ============================
# Hard Tasks: 10
# Easy Tasks: 94
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 52
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 10 from the total of 105
# Task consensus: 16 of 105
# Accuracy Simulation: 0.1523809523809524
# ============================
# Hard Tasks: 11
# Easy Tasks: 95
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 53
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 20
# Tasks already done 8 from the total of 106
# Task consensus: 30 of 106
# Accuracy Simulation: 0.2830188679245283
# ============================
# Hard Tasks: 11
# Easy Tasks: 96
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 53
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.855
# Selected Best Workers: 19
# Tasks already done 11 from the total of 107
# Task consensus: 37 of 107
# Accuracy Simulation: 0.34579439252336447
# ============================
# Hard Tasks: 11
# Easy Tasks: 97
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 54
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 8 from the total of 108
# Task consensus: 22 of 108
# Accuracy Simulation: 0.2037037037037037
# ============================
# Hard Tasks: 11
# Easy Tasks: 98
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 54
# Workers Trained: 50
# Cutoff for Performance: 0.058
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 7 from the total of 109
# Task consensus: 31 of 109
# Accuracy Simulation: 0.28440366972477066
# ============================
# Hard Tasks: 11
# Easy Tasks: 99
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 55
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.85
# Selected Best Workers: 11
# Tasks already done 15 from the total of 110
# Task consensus: 34 of 110
# Accuracy Simulation: 0.3090909090909091
# ============================
# Hard Tasks: 11
# Easy Tasks: 100
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 55
# Workers Trained: 50
# Cutoff for Performance: 0.089
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 7 from the total of 111
# Task consensus: 32 of 111
# Accuracy Simulation: 0.2882882882882883
# ============================
# Hard Tasks: 11
# Easy Tasks: 101
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 56
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 16
# Tasks already done 8 from the total of 112
# Task consensus: 34 of 112
# Accuracy Simulation: 0.30357142857142855
# ============================
# Hard Tasks: 11
# Easy Tasks: 102
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 56
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.895
# Selected Best Workers: 18
# Tasks already done 11 from the total of 113
# Task consensus: 36 of 113
# Accuracy Simulation: 0.3185840707964602
# ============================
# Hard Tasks: 11
# Easy Tasks: 103
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 57
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 12 from the total of 114
# Task consensus: 29 of 114
# Accuracy Simulation: 0.2543859649122807
# ============================
# Hard Tasks: 12
# Easy Tasks: 104
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 57
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.84
# Selected Best Workers: 12
# Tasks already done 12 from the total of 115
# Task consensus: 37 of 115
# Accuracy Simulation: 0.3217391304347826
# ============================
# Hard Tasks: 12
# Easy Tasks: 104
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 58
# Workers Trained: 50
# Cutoff for Performance: 0.08
# Cutoff for Probability: 0.835
# Selected Best Workers: 14
# Tasks already done 8 from the total of 116
# Task consensus: 35 of 116
# Accuracy Simulation: 0.3017241379310345
# ============================
# Hard Tasks: 12
# Easy Tasks: 105
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 58
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 11 from the total of 117
# Task consensus: 35 of 117
# Accuracy Simulation: 0.29914529914529914
# ============================
# Hard Tasks: 12
# Easy Tasks: 106
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 59
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.87
# Selected Best Workers: 15
# Tasks already done 13 from the total of 118
# Task consensus: 35 of 118
# Accuracy Simulation: 0.2966101694915254
# ============================
# Hard Tasks: 12
# Easy Tasks: 107
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 59
# Workers Trained: 50
# Cutoff for Performance: 0.05
# Cutoff for Probability: 0.845
# Selected Best Workers: 19
# Tasks already done 7 from the total of 119
# Task consensus: 29 of 119
# Accuracy Simulation: 0.24369747899159663
# ============================
# Hard Tasks: 12
# Easy Tasks: 108
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 60
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 17
# Tasks already done 8 from the total of 120
# Task consensus: 29 of 120
# Accuracy Simulation: 0.24166666666666667
# ============================
# Hard Tasks: 12
# Easy Tasks: 109
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 60
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 8 from the total of 121
# Task consensus: 33 of 121
# Accuracy Simulation: 0.2727272727272727
# ============================
# Hard Tasks: 12
# Easy Tasks: 110
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 61
# Workers Trained: 50
# Cutoff for Performance: 0.117
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 12 from the total of 122
# Task consensus: 36 of 122
# Accuracy Simulation: 0.29508196721311475
# ============================
# Hard Tasks: 12
# Easy Tasks: 111
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 61
# Workers Trained: 50
# Cutoff for Performance: 0.177
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 14 from the total of 123
# Task consensus: 35 of 123
# Accuracy Simulation: 0.2845528455284553
# ============================
# Hard Tasks: 12
# Easy Tasks: 112
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 62
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.84
# Selected Best Workers: 17
# Tasks already done 13 from the total of 124
# Task consensus: 29 of 124
# Accuracy Simulation: 0.23387096774193547
# ============================
# Hard Tasks: 12
# Easy Tasks: 112
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 62
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.875
# Selected Best Workers: 17
# Tasks already done 13 from the total of 125
# Task consensus: 30 of 125
# Accuracy Simulation: 0.24
# ============================
# Hard Tasks: 13
# Easy Tasks: 113
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 63
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 12 from the total of 126
# Task consensus: 34 of 126
# Accuracy Simulation: 0.2698412698412698
# ============================
# Hard Tasks: 13
# Easy Tasks: 114
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 63
# Workers Trained: 50
# Cutoff for Performance: 0.105
# Cutoff for Probability: 0.81
# Selected Best Workers: 15
# Tasks already done 9 from the total of 127
# Task consensus: 35 of 127
# Accuracy Simulation: 0.2755905511811024
# ============================
# Hard Tasks: 13
# Easy Tasks: 115
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 64
# Workers Trained: 50
# Cutoff for Performance: 0.25
# Cutoff for Probability: 0.85
# Selected Best Workers: 13
# Tasks already done 18 from the total of 128
# Task consensus: 42 of 128
# Accuracy Simulation: 0.328125
# ============================
# Hard Tasks: 13
# Easy Tasks: 116
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 64
# Workers Trained: 50
# Cutoff for Performance: 0.182
# Cutoff for Probability: 0.88
# Selected Best Workers: 16
# Tasks already done 17 from the total of 129
# Task consensus: 42 of 129
# Accuracy Simulation: 0.32558139534883723
# ============================
# Hard Tasks: 13
# Easy Tasks: 117
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 65
# Workers Trained: 50
# Cutoff for Performance: 0.166
# Cutoff for Probability: 0.87
# Selected Best Workers: 18
# Tasks already done 16 from the total of 130
# Task consensus: 46 of 130
# Accuracy Simulation: 0.35384615384615387
# ============================
# Hard Tasks: 13
# Easy Tasks: 118
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 65
# Workers Trained: 50
# Cutoff for Performance: 0.105
# Cutoff for Probability: 0.87
# Selected Best Workers: 19
# Tasks already done 11 from the total of 131
# Task consensus: 40 of 131
# Accuracy Simulation: 0.3053435114503817
# ============================
# Hard Tasks: 13
# Easy Tasks: 119
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 66
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 11 from the total of 132
# Task consensus: 26 of 132
# Accuracy Simulation: 0.19696969696969696
# ============================
# Hard Tasks: 13
# Easy Tasks: 120
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 66
# Workers Trained: 50
# Cutoff for Performance: 0.222
# Cutoff for Probability: 0.855
# Selected Best Workers: 17
# Tasks already done 21 from the total of 133
# Task consensus: 29 of 133
# Accuracy Simulation: 0.21804511278195488
# ============================
# Hard Tasks: 13
# Easy Tasks: 121
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 67
# Workers Trained: 50
# Cutoff for Performance: 0.044
# Cutoff for Probability: 0.88
# Selected Best Workers: 17
# Tasks already done 11 from the total of 134
# Task consensus: 37 of 134
# Accuracy Simulation: 0.27611940298507465
# ============================
# Hard Tasks: 14
# Easy Tasks: 122
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 67
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 10 from the total of 135
# Task consensus: 31 of 135
# Accuracy Simulation: 0.22962962962962963
# ============================
# Hard Tasks: 14
# Easy Tasks: 122
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 68
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.85
# Selected Best Workers: 14
# Tasks already done 11 from the total of 136
# Task consensus: 30 of 136
# Accuracy Simulation: 0.22058823529411764
# ============================
# Hard Tasks: 14
# Easy Tasks: 123
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 68
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.855
# Selected Best Workers: 18
# Tasks already done 18 from the total of 137
# Task consensus: 40 of 137
# Accuracy Simulation: 0.291970802919708
# ============================
# Hard Tasks: 14
# Easy Tasks: 124
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 69
# Workers Trained: 50
# Cutoff for Performance: 0.177
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 16 from the total of 138
# Task consensus: 37 of 138
# Accuracy Simulation: 0.26811594202898553
# ============================
# Hard Tasks: 14
# Easy Tasks: 125
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 69
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.84
# Selected Best Workers: 14
# Tasks already done 21 from the total of 139
# Task consensus: 44 of 139
# Accuracy Simulation: 0.31654676258992803
# ============================
# Hard Tasks: 14
# Easy Tasks: 126
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 70
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.865
# Selected Best Workers: 15
# Tasks already done 18 from the total of 140
# Task consensus: 49 of 140
# Accuracy Simulation: 0.35
# ============================
# Hard Tasks: 14
# Easy Tasks: 127
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 70
# Workers Trained: 50
# Cutoff for Performance: 0.133
# Cutoff for Probability: 0.855
# Selected Best Workers: 20
# Tasks already done 15 from the total of 141
# Task consensus: 49 of 141
# Accuracy Simulation: 0.3475177304964539
# ============================
# Hard Tasks: 14
# Easy Tasks: 128
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 71
# Workers Trained: 50
# Cutoff for Performance: 0.164
# Cutoff for Probability: 0.895
# Selected Best Workers: 14
# Tasks already done 14 from the total of 142
# Task consensus: 40 of 142
# Accuracy Simulation: 0.28169014084507044
# ============================
# Hard Tasks: 14
# Easy Tasks: 129
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 71
# Workers Trained: 50
# Cutoff for Performance: 0.21
# Cutoff for Probability: 0.835
# Selected Best Workers: 16
# Tasks already done 21 from the total of 143
# Task consensus: 51 of 143
# Accuracy Simulation: 0.35664335664335667
# ============================
# Hard Tasks: 14
# Easy Tasks: 130
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 72
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.88
# Selected Best Workers: 15
# Tasks already done 17 from the total of 144
# Task consensus: 50 of 144
# Accuracy Simulation: 0.3472222222222222
# ============================
# Hard Tasks: 14
# Easy Tasks: 130
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 72
# Workers Trained: 50
# Cutoff for Performance: 0.174
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 16 from the total of 145
# Task consensus: 46 of 145
# Accuracy Simulation: 0.31724137931034485
# ============================
# Hard Tasks: 15
# Easy Tasks: 131
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 73
# Workers Trained: 50
# Cutoff for Performance: 0.196
# Cutoff for Probability: 0.835
# Selected Best Workers: 19
# Tasks already done 17 from the total of 146
# Task consensus: 52 of 146
# Accuracy Simulation: 0.3561643835616438
# ============================
# Hard Tasks: 15
# Easy Tasks: 132
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 73
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.87
# Selected Best Workers: 12
# Tasks already done 13 from the total of 147
# Task consensus: 36 of 147
# Accuracy Simulation: 0.24489795918367346
# ============================
# Hard Tasks: 15
# Easy Tasks: 133
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 74
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.84
# Selected Best Workers: 17
# Tasks already done 14 from the total of 148
# Task consensus: 41 of 148
# Accuracy Simulation: 0.27702702702702703
# ============================
# Hard Tasks: 15
# Easy Tasks: 134
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 74
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 18 from the total of 149
# Task consensus: 32 of 149
# Accuracy Simulation: 0.21476510067114093
# ============================
# Hard Tasks: 15
# Easy Tasks: 135
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 75
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 14 from the total of 150
# Task consensus: 42 of 150
# Accuracy Simulation: 0.28
# ============================
# Hard Tasks: 15
# Easy Tasks: 136
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 75
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.855
# Selected Best Workers: 17
# Tasks already done 13 from the total of 151
# Task consensus: 48 of 151
# Accuracy Simulation: 0.31788079470198677
# ============================
# Hard Tasks: 15
# Easy Tasks: 137
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 76
# Workers Trained: 50
# Cutoff for Performance: 0.163
# Cutoff for Probability: 0.84
# Selected Best Workers: 19
# Tasks already done 17 from the total of 152
# Task consensus: 45 of 152
# Accuracy Simulation: 0.29605263157894735
# ============================
# Hard Tasks: 15
# Easy Tasks: 138
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 76
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.855
# Selected Best Workers: 22
# Tasks already done 17 from the total of 153
# Task consensus: 35 of 153
# Accuracy Simulation: 0.22875816993464052
# ============================
# Hard Tasks: 15
# Easy Tasks: 139
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 77
# Workers Trained: 50
# Cutoff for Performance: 0.16
# Cutoff for Probability: 0.83
# Selected Best Workers: 16
# Tasks already done 22 from the total of 154
# Task consensus: 45 of 154
# Accuracy Simulation: 0.2922077922077922
# ============================
# Hard Tasks: 16
# Easy Tasks: 140
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 77
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.87
# Selected Best Workers: 15
# Tasks already done 23 from the total of 155
# Task consensus: 48 of 155
# Accuracy Simulation: 0.3096774193548387
# ============================
# Hard Tasks: 16
# Easy Tasks: 140
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 78
# Workers Trained: 50
# Cutoff for Performance: 0.154
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 17 from the total of 156
# Task consensus: 33 of 156
# Accuracy Simulation: 0.21153846153846154
# ============================
# Hard Tasks: 16
# Easy Tasks: 141
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 78
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.88
# Selected Best Workers: 15
# Tasks already done 13 from the total of 157
# Task consensus: 51 of 157
# Accuracy Simulation: 0.3248407643312102
# ============================
# Hard Tasks: 16
# Easy Tasks: 142
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 79
# Workers Trained: 50
# Cutoff for Performance: 0.089
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 14 from the total of 158
# Task consensus: 54 of 158
# Accuracy Simulation: 0.34177215189873417
# ============================
# Hard Tasks: 16
# Easy Tasks: 143
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 79
# Workers Trained: 50
# Cutoff for Performance: 0.154
# Cutoff for Probability: 0.855
# Selected Best Workers: 17
# Tasks already done 17 from the total of 159
# Task consensus: 47 of 159
# Accuracy Simulation: 0.29559748427672955
# ============================
# Hard Tasks: 16
# Easy Tasks: 144
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 80
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 15 from the total of 160
# Task consensus: 45 of 160
# Accuracy Simulation: 0.28125
# ============================
# Hard Tasks: 16
# Easy Tasks: 145
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 80
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.83
# Selected Best Workers: 17
# Tasks already done 14 from the total of 161
# Task consensus: 44 of 161
# Accuracy Simulation: 0.2732919254658385
# ============================
# Hard Tasks: 16
# Easy Tasks: 146
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 81
# Workers Trained: 50
# Cutoff for Performance: 0.071
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 9 from the total of 162
# Task consensus: 50 of 162
# Accuracy Simulation: 0.30864197530864196
# ============================
# Hard Tasks: 16
# Easy Tasks: 147
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 81
# Workers Trained: 50
# Cutoff for Performance: 0.151
# Cutoff for Probability: 0.875
# Selected Best Workers: 19
# Tasks already done 18 from the total of 163
# Task consensus: 37 of 163
# Accuracy Simulation: 0.22699386503067484
# ============================
# Hard Tasks: 16
# Easy Tasks: 148
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 82
# Workers Trained: 50
# Cutoff for Performance: 0.095
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 11 from the total of 164
# Task consensus: 46 of 164
# Accuracy Simulation: 0.2804878048780488
# ============================
# Hard Tasks: 16
# Easy Tasks: 148
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 82
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 16 from the total of 165
# Task consensus: 56 of 165
# Accuracy Simulation: 0.3393939393939394
# ============================
# Hard Tasks: 17
# Easy Tasks: 149
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 83
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 17
# Tasks already done 6 from the total of 166
# Task consensus: 41 of 166
# Accuracy Simulation: 0.2469879518072289
# ============================
# Hard Tasks: 17
# Easy Tasks: 150
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 83
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.855
# Selected Best Workers: 17
# Tasks already done 16 from the total of 167
# Task consensus: 51 of 167
# Accuracy Simulation: 0.30538922155688625
# ============================
# Hard Tasks: 17
# Easy Tasks: 151
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 84
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.815
# Selected Best Workers: 20
# Tasks already done 18 from the total of 168
# Task consensus: 39 of 168
# Accuracy Simulation: 0.23214285714285715
# ============================
# Hard Tasks: 17
# Easy Tasks: 152
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 84
# Workers Trained: 50
# Cutoff for Performance: 0.21
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 21 from the total of 169
# Task consensus: 35 of 169
# Accuracy Simulation: 0.20710059171597633
# ============================
# Hard Tasks: 17
# Easy Tasks: 153
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 85
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.83
# Selected Best Workers: 17
# Tasks already done 14 from the total of 170
# Task consensus: 49 of 170
# Accuracy Simulation: 0.28823529411764703
# ============================
# Hard Tasks: 17
# Easy Tasks: 154
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 85
# Workers Trained: 50
# Cutoff for Performance: 0.083
# Cutoff for Probability: 0.87
# Selected Best Workers: 17
# Tasks already done 12 from the total of 171
# Task consensus: 49 of 171
# Accuracy Simulation: 0.28654970760233917
# ============================
# Hard Tasks: 17
# Easy Tasks: 155
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 86
# Workers Trained: 50
# Cutoff for Performance: 0.104
# Cutoff for Probability: 0.86
# Selected Best Workers: 18
# Tasks already done 12 from the total of 172
# Task consensus: 47 of 172
# Accuracy Simulation: 0.27325581395348836
# ============================
# Hard Tasks: 17
# Easy Tasks: 156
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 86
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.86
# Selected Best Workers: 19
# Tasks already done 14 from the total of 173
# Task consensus: 42 of 173
# Accuracy Simulation: 0.24277456647398843
# ============================
# Hard Tasks: 17
# Easy Tasks: 157
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 87
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.88
# Selected Best Workers: 17
# Tasks already done 15 from the total of 174
# Task consensus: 27 of 174
# Accuracy Simulation: 0.15517241379310345
# ============================
# Hard Tasks: 18
# Easy Tasks: 158
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 87
# Workers Trained: 50
# Cutoff for Performance: 0.154
# Cutoff for Probability: 0.84
# Selected Best Workers: 14
# Tasks already done 19 from the total of 175
# Task consensus: 48 of 175
# Accuracy Simulation: 0.2742857142857143
# ============================
# Hard Tasks: 18
# Easy Tasks: 158
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 88
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 21 from the total of 176
# Task consensus: 40 of 176
# Accuracy Simulation: 0.22727272727272727
# ============================
# Hard Tasks: 18
# Easy Tasks: 159
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 88
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 13 from the total of 177
# Task consensus: 30 of 177
# Accuracy Simulation: 0.1694915254237288
# ============================
# Hard Tasks: 18
# Easy Tasks: 160
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 89
# Workers Trained: 50
# Cutoff for Performance: 0.091
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 15 from the total of 178
# Task consensus: 36 of 178
# Accuracy Simulation: 0.20224719101123595
# ============================
# Hard Tasks: 18
# Easy Tasks: 161
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 89
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.875
# Selected Best Workers: 16
# Tasks already done 24 from the total of 179
# Task consensus: 58 of 179
# Accuracy Simulation: 0.3240223463687151
# ============================
# Hard Tasks: 18
# Easy Tasks: 162
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 90
# Workers Trained: 50
# Cutoff for Performance: 0.163
# Cutoff for Probability: 0.86
# Selected Best Workers: 18
# Tasks already done 19 from the total of 180
# Task consensus: 62 of 180
# Accuracy Simulation: 0.34444444444444444
# ============================
# Hard Tasks: 18
# Easy Tasks: 163
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 90
# Workers Trained: 50
# Cutoff for Performance: 0.148
# Cutoff for Probability: 0.845
# Selected Best Workers: 17
# Tasks already done 19 from the total of 181
# Task consensus: 49 of 181
# Accuracy Simulation: 0.27071823204419887
# ============================
# Hard Tasks: 18
# Easy Tasks: 164
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 91
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.815
# Selected Best Workers: 17
# Tasks already done 13 from the total of 182
# Task consensus: 54 of 182
# Accuracy Simulation: 0.2967032967032967
# ============================
# Hard Tasks: 18
# Easy Tasks: 165
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 91
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 12 from the total of 183
# Task consensus: 60 of 183
# Accuracy Simulation: 0.32786885245901637
# ============================
# Hard Tasks: 18
# Easy Tasks: 166
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 92
# Workers Trained: 50
# Cutoff for Performance: 0.083
# Cutoff for Probability: 0.87
# Selected Best Workers: 17
# Tasks already done 11 from the total of 184
# Task consensus: 44 of 184
# Accuracy Simulation: 0.2391304347826087
# ============================
# Hard Tasks: 18
# Easy Tasks: 166
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 92
# Workers Trained: 50
# Cutoff for Performance: 0.14
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 21 from the total of 185
# Task consensus: 56 of 185
# Accuracy Simulation: 0.3027027027027027
# ============================
# Hard Tasks: 19
# Easy Tasks: 167
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 93
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.895
# Selected Best Workers: 17
# Tasks already done 15 from the total of 186
# Task consensus: 49 of 186
# Accuracy Simulation: 0.26344086021505375
# ============================
# Hard Tasks: 19
# Easy Tasks: 168
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 93
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 15 from the total of 187
# Task consensus: 48 of 187
# Accuracy Simulation: 0.25668449197860965
# ============================
# Hard Tasks: 19
# Easy Tasks: 169
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 94
# Workers Trained: 50
# Cutoff for Performance: 0.174
# Cutoff for Probability: 0.86
# Selected Best Workers: 19
# Tasks already done 21 from the total of 188
# Task consensus: 54 of 188
# Accuracy Simulation: 0.2872340425531915
# ============================
# Hard Tasks: 19
# Easy Tasks: 170
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 94
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.865
# Selected Best Workers: 13
# Tasks already done 19 from the total of 189
# Task consensus: 63 of 189
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 19
# Easy Tasks: 171
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 95
# Workers Trained: 50
# Cutoff for Performance: 0.174
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 23 from the total of 190
# Task consensus: 71 of 190
# Accuracy Simulation: 0.3736842105263158
# ============================
# Hard Tasks: 19
# Easy Tasks: 172
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 95
# Workers Trained: 50
# Cutoff for Performance: 0.083
# Cutoff for Probability: 0.865
# Selected Best Workers: 17
# Tasks already done 14 from the total of 191
# Task consensus: 36 of 191
# Accuracy Simulation: 0.18848167539267016
# ============================
# Hard Tasks: 19
# Easy Tasks: 173
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 96
# Workers Trained: 50
# Cutoff for Performance: 0.154
# Cutoff for Probability: 0.88
# Selected Best Workers: 18
# Tasks already done 19 from the total of 192
# Task consensus: 54 of 192
# Accuracy Simulation: 0.28125
# ============================
# Hard Tasks: 19
# Easy Tasks: 174
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 96
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 17 from the total of 193
# Task consensus: 53 of 193
# Accuracy Simulation: 0.27461139896373055
# ============================
# Hard Tasks: 19
# Easy Tasks: 175
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 97
# Workers Trained: 50
# Cutoff for Performance: 0.174
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 25 from the total of 194
# Task consensus: 51 of 194
# Accuracy Simulation: 0.26288659793814434
# ============================
# Hard Tasks: 20
# Easy Tasks: 176
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 97
# Workers Trained: 50
# Cutoff for Performance: 0.148
# Cutoff for Probability: 0.845
# Selected Best Workers: 16
# Tasks already done 18 from the total of 195
# Task consensus: 56 of 195
# Accuracy Simulation: 0.28717948717948716
# ============================
# Hard Tasks: 20
# Easy Tasks: 176
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 98
# Workers Trained: 50
# Cutoff for Performance: 0.09
# Cutoff for Probability: 0.86
# Selected Best Workers: 18
# Tasks already done 14 from the total of 196
# Task consensus: 60 of 196
# Accuracy Simulation: 0.30612244897959184
# ============================
# Hard Tasks: 20
# Easy Tasks: 177
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 98
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 21 from the total of 197
# Task consensus: 36 of 197
# Accuracy Simulation: 0.18274111675126903
# ============================
# Hard Tasks: 20
# Easy Tasks: 178
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 99
# Workers Trained: 50
# Cutoff for Performance: 0.18
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 22 from the total of 198
# Task consensus: 65 of 198
# Accuracy Simulation: 0.3282828282828283
# ============================
# Hard Tasks: 20
# Easy Tasks: 179
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 99
# Workers Trained: 50
# Cutoff for Performance: 0.22
# Cutoff for Probability: 0.84
# Selected Best Workers: 14
# Tasks already done 28 from the total of 199
# Task consensus: 60 of 199
# Accuracy Simulation: 0.3015075376884422
# ============================
# Hard Tasks: 20
# Easy Tasks: 180
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 100
# Workers Trained: 50
# Cutoff for Performance: 0.106
# Cutoff for Probability: 0.86
# Selected Best Workers: 19
# Tasks already done 17 from the total of 200
# Task consensus: 32 of 200
# Accuracy Simulation: 0.16
# ============================

# %%
results
# Out:
# [(10, 0.4166666666666667),
#  (11, 0.6153846153846154),
#  (14, 0.625),
#  (16, 0.5),
#  (17, 0.3684210526315789),
#  (18, 0.45),
#  (19, 0.3333333333333333),
#  (21, 0.43478260869565216),
#  (23, 0.48),
#  (24, 0.23076923076923078),
#  (26, 0.39285714285714285),
#  (28, 0.4),
#  (29, 0.5161290322580645),
#  (31, 0.18181818181818182),
#  (32, 0.47058823529411764),
#  (33, 0.2857142857142857),
#  (34, 0.2777777777777778),
#  (35, 0.2972972972972973),
#  (36, 0.2631578947368421),
#  (37, 0.3333333333333333),
#  (38, 0.25),
#  (39, 0.3902439024390244),
#  (40, 0.35714285714285715),
#  (42, 0.4318181818181818),
#  (43, 0.35555555555555557),
#  (44, 0.30434782608695654),
#  (45, 0.23404255319148937),
#  (46, 0.3333333333333333),
#  (47, 0.42857142857142855),
#  (48, 0.34),
#  (49, 0.3137254901960784),
#  (50, 0.3269230769230769),
#  (51, 0.2830188679245283),
#  (52, 0.3888888888888889),
#  (53, 0.36363636363636365),
#  (54, 0.375),
#  (55, 0.2807017543859649),
#  (56, 0.3103448275862069),
#  (57, 0.3728813559322034),
#  (58, 0.31666666666666665),
#  (59, 0.32786885245901637),
#  (60, 0.3225806451612903),
#  (61, 0.2857142857142857),
#  (62, 0.328125),
#  (63, 0.24615384615384617),
#  (64, 0.16666666666666666),
#  (65, 0.3283582089552239),
#  (66, 0.3088235294117647),
#  (67, 0.2463768115942029),
#  (68, 0.37142857142857144),
#  (69, 0.2112676056338028),
#  (70, 0.3611111111111111),
#  (71, 0.136986301369863),
#  (72, 0.36486486486486486),
#  (73, 0.26666666666666666),
#  (74, 0.2894736842105263),
#  (75, 0.22077922077922077),
#  (76, 0.1794871794871795),
#  (77, 0.3037974683544304),
#  (78, 0.3625),
#  (79, 0.37037037037037035),
#  (80, 0.1951219512195122),
#  (81, 0.30120481927710846),
#  (82, 0.2619047619047619),
#  (83, 0.3411764705882353),
#  (84, 0.36046511627906974),
#  (85, 0.39080459770114945),
#  (86, 0.29545454545454547),
#  (87, 0.2808988764044944),
#  (88, 0.3111111111111111),
#  (89, 0.27472527472527475),
#  (90, 0.2608695652173913),
#  (91, 0.15053763440860216),
#  (92, 0.3617021276595745),
#  (93, 0.24210526315789474),
#  (94, 0.14583333333333334),
#  (95, 0.25773195876288657),
#  (96, 0.29591836734693877),
#  (97, 0.2828282828282828),
#  (98, 0.23),
#  (99, 0.36633663366336633),
#  (100, 0.22549019607843138),
#  (101, 0.2912621359223301),
#  (102, 0.34615384615384615),
#  (103, 0.1523809523809524),
#  (104, 0.2830188679245283),
#  (105, 0.34579439252336447),
#  (106, 0.2037037037037037),
#  (107, 0.28440366972477066),
#  (108, 0.3090909090909091),
#  (109, 0.2882882882882883),
#  (110, 0.30357142857142855),
#  (111, 0.3185840707964602),
#  (112, 0.2543859649122807),
#  (113, 0.3217391304347826),
#  (114, 0.3017241379310345),
#  (115, 0.29914529914529914),
#  (116, 0.2966101694915254),
#  (117, 0.24369747899159663),
#  (118, 0.24166666666666667),
#  (119, 0.2727272727272727),
#  (120, 0.29508196721311475),
#  (121, 0.2845528455284553),
#  (122, 0.23387096774193547),
#  (123, 0.24),
#  (124, 0.2698412698412698),
#  (125, 0.2755905511811024),
#  (126, 0.328125),
#  (127, 0.32558139534883723),
#  (128, 0.35384615384615387),
#  (129, 0.3053435114503817),
#  (130, 0.19696969696969696),
#  (131, 0.21804511278195488),
#  (132, 0.27611940298507465),
#  (133, 0.22962962962962963),
#  (134, 0.22058823529411764),
#  (135, 0.291970802919708),
#  (136, 0.26811594202898553),
#  (137, 0.31654676258992803),
#  (138, 0.35),
#  (139, 0.3475177304964539),
#  (140, 0.28169014084507044),
#  (141, 0.35664335664335667),
#  (142, 0.3472222222222222),
#  (143, 0.31724137931034485),
#  (144, 0.3561643835616438),
#  (145, 0.24489795918367346),
#  (146, 0.27702702702702703),
#  (147, 0.21476510067114093),
#  (148, 0.28),
#  (149, 0.31788079470198677),
#  (150, 0.29605263157894735),
#  (151, 0.22875816993464052),
#  (152, 0.2922077922077922),
#  (153, 0.3096774193548387),
#  (154, 0.21153846153846154),
#  (155, 0.3248407643312102),
#  (156, 0.34177215189873417),
#  (157, 0.29559748427672955),
#  (158, 0.28125),
#  (159, 0.2732919254658385),
#  (160, 0.30864197530864196),
#  (161, 0.22699386503067484),
#  (162, 0.2804878048780488),
#  (163, 0.3393939393939394),
#  (164, 0.2469879518072289),
#  (165, 0.30538922155688625),
#  (166, 0.23214285714285715),
#  (167, 0.20710059171597633),
#  (168, 0.28823529411764703),
#  (169, 0.28654970760233917),
#  (170, 0.27325581395348836),
#  (171, 0.24277456647398843),
#  (172, 0.15517241379310345),
#  (173, 0.2742857142857143),
#  (174, 0.22727272727272727),
#  (175, 0.1694915254237288),
#  (176, 0.20224719101123595),
#  (177, 0.3240223463687151),
#  (178, 0.34444444444444444),
#  (179, 0.27071823204419887),
#  (180, 0.2967032967032967),
#  (181, 0.32786885245901637),
#  (182, 0.2391304347826087),
#  (183, 0.3027027027027027),
#  (184, 0.26344086021505375),
#  (185, 0.25668449197860965),
#  (186, 0.2872340425531915),
#  (187, 0.3333333333333333),
#  (188, 0.3736842105263158),
#  (189, 0.18848167539267016),
#  (190, 0.28125),
#  (191, 0.27461139896373055),
#  (192, 0.26288659793814434),
#  (193, 0.28717948717948716),
#  (194, 0.30612244897959184),
#  (195, 0.18274111675126903),
#  (196, 0.3282828282828283),
#  (197, 0.3015075376884422),
#  (198, 0.16)]

# %%
def simulations_df(max_value, variable, number_simulations = 10):
    startTime= dt.now()
    simulations = []
    for k in range(number_simulations):
        results = train_parameter(max_value)
        simulations.append((k, results))

    df_simulations = pd.DataFrame()
    vec_variable, vec_accuracy, vec_simulation = [], [], []
    for i in simulations:
        for j in i[1]:
            vec_variable.append(j[0])
            vec_accuracy.append(j[1])
            vec_simulation.append(i[0])

    df_simulations['variable'] = vec_variable
    df_simulations['accuracy'] = vec_accuracy
    df_simulations['simulation'] = vec_simulation
    
    df_simulations.to_csv('df_simulations'+str(variable)+str(max_value)+'.csv', sep=',', encoding="utf-8")
    
    timeElapsed = dt.now()-startTime
    print('Process (hh:mm:ss.ms) {}'.format(timeElapsed))
    
    return df_simulations, timeElapsed

# %%
#total_tasks
df_simulations, timeElapsed = simulations_df(500, "total_tasks", 30)
# Out:
# Hard Tasks: 0
# Easy Tasks: 2
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 1
# Workers Trained: 7
# Cutoff for Performance: 0.8
# Cutoff for Probability: 0.93
# Selected Best Workers: 2
# Tasks already done 1 from the total of 2
# Hard Tasks: 0
# Easy Tasks: 3
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 1
# Workers Trained: 7
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 0
# Tasks already done 1 from the total of 3
# Hard Tasks: 0
# Easy Tasks: 4
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 2
# Workers Trained: 12
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 3
# Tasks already done 1 from the total of 4
# Hard Tasks: 0
# Easy Tasks: 4
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 2
# Workers Trained: 14
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.81
# Selected Best Workers: 0
# Tasks already done 2 from the total of 5
# Hard Tasks: 1
# Easy Tasks: 5
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 3
# Workers Trained: 21
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 0
# Tasks already done 3 from the total of 6
# Hard Tasks: 1
# Easy Tasks: 6
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 3
# Workers Trained: 17
# Cutoff for Performance: 0.4
# Cutoff for Probability: 0.76
# Selected Best Workers: 7
# Tasks already done 2 from the total of 7
# Task consensus: 5 of 7
# Accuracy Simulation: 0.7142857142857143
# ============================
# Hard Tasks: 1
# Easy Tasks: 7
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 4
# Workers Trained: 20
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 4
# Tasks already done 2 from the total of 8
# Hard Tasks: 1
# Easy Tasks: 8
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 4
# Workers Trained: 22
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 5
# Tasks already done 2 from the total of 9
# Hard Tasks: 1
# Easy Tasks: 9
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 5
# Workers Trained: 29
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 5
# Tasks already done 2 from the total of 10
# Hard Tasks: 1
# Easy Tasks: 10
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 5
# Workers Trained: 28
# Cutoff for Performance: 1.0
# Cutoff for Probability: 0.835
# Selected Best Workers: 0
# Tasks already done 5 from the total of 11
# Hard Tasks: 1
# Easy Tasks: 11
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 6
# Workers Trained: 34
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 5
# Tasks already done 2 from the total of 12
# Hard Tasks: 1
# Easy Tasks: 12
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 6
# Workers Trained: 27
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 8
# Tasks already done 3 from the total of 13
# Task consensus: 5 of 13
# Accuracy Simulation: 0.38461538461538464
# ============================
# Hard Tasks: 1
# Easy Tasks: 13
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 7
# Workers Trained: 33
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.81
# Selected Best Workers: 9
# Tasks already done 4 from the total of 14
# Task consensus: 6 of 14
# Accuracy Simulation: 0.42857142857142855
# ============================
# Hard Tasks: 2
# Easy Tasks: 14
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 7
# Workers Trained: 33
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 6
# Tasks already done 2 from the total of 15
# Hard Tasks: 2
# Easy Tasks: 14
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 8
# Workers Trained: 33
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 8
# Tasks already done 5 from the total of 16
# Task consensus: 6 of 16
# Accuracy Simulation: 0.375
# ============================
# Hard Tasks: 2
# Easy Tasks: 15
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 8
# Workers Trained: 33
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 10
# Tasks already done 3 from the total of 17
# Task consensus: 8 of 17
# Accuracy Simulation: 0.47058823529411764
# ============================
# Hard Tasks: 2
# Easy Tasks: 16
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 9
# Workers Trained: 39
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 3
# Tasks already done 2 from the total of 18
# Hard Tasks: 2
# Easy Tasks: 17
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 9
# Workers Trained: 35
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 7
# Tasks already done 2 from the total of 19
# Task consensus: 6 of 19
# Accuracy Simulation: 0.3157894736842105
# ============================
# Hard Tasks: 2
# Easy Tasks: 18
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 10
# Workers Trained: 38
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 7
# Tasks already done 3 from the total of 20
# Task consensus: 7 of 20
# Accuracy Simulation: 0.35
# ============================
# Hard Tasks: 2
# Easy Tasks: 19
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 10
# Workers Trained: 39
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 6
# Tasks already done 1 from the total of 21
# Hard Tasks: 2
# Easy Tasks: 20
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 11
# Workers Trained: 39
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 9
# Tasks already done 4 from the total of 22
# Task consensus: 7 of 22
# Accuracy Simulation: 0.3181818181818182
# ============================
# Hard Tasks: 2
# Easy Tasks: 21
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 11
# Workers Trained: 43
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 12
# Tasks already done 3 from the total of 23
# Task consensus: 7 of 23
# Accuracy Simulation: 0.30434782608695654
# ============================
# Hard Tasks: 2
# Easy Tasks: 22
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 12
# Workers Trained: 38
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 12
# Tasks already done 5 from the total of 24
# Task consensus: 8 of 24
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 2
# Easy Tasks: 22
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 12
# Workers Trained: 42
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.845
# Selected Best Workers: 9
# Tasks already done 3 from the total of 25
# Task consensus: 10 of 25
# Accuracy Simulation: 0.4
# ============================
# Hard Tasks: 3
# Easy Tasks: 23
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 13
# Workers Trained: 43
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 7
# Tasks already done 4 from the total of 26
# Task consensus: 11 of 26
# Accuracy Simulation: 0.4230769230769231
# ============================
# Hard Tasks: 3
# Easy Tasks: 24
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 13
# Workers Trained: 45
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 3
# Tasks already done 2 from the total of 27
# Hard Tasks: 3
# Easy Tasks: 25
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 14
# Workers Trained: 46
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.875
# Selected Best Workers: 7
# Tasks already done 3 from the total of 28
# Task consensus: 7 of 28
# Accuracy Simulation: 0.25
# ============================
# Hard Tasks: 3
# Easy Tasks: 26
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 14
# Workers Trained: 47
# Cutoff for Performance: 0.333
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 8 from the total of 29
# Task consensus: 15 of 29
# Accuracy Simulation: 0.5172413793103449
# ============================
# Hard Tasks: 3
# Easy Tasks: 27
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 15
# Workers Trained: 46
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 5 from the total of 30
# Task consensus: 9 of 30
# Accuracy Simulation: 0.3
# ============================
# Hard Tasks: 3
# Easy Tasks: 28
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 15
# Workers Trained: 45
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.89
# Selected Best Workers: 12
# Tasks already done 4 from the total of 31
# Task consensus: 9 of 31
# Accuracy Simulation: 0.2903225806451613
# ============================
# Hard Tasks: 3
# Easy Tasks: 29
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 16
# Workers Trained: 46
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 14
# Tasks already done 5 from the total of 32
# Task consensus: 14 of 32
# Accuracy Simulation: 0.4375
# ============================
# Hard Tasks: 3
# Easy Tasks: 30
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 16
# Workers Trained: 46
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 1
# Tasks already done 1 from the total of 33
# Hard Tasks: 3
# Easy Tasks: 31
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 17
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 9
# Tasks already done 3 from the total of 34
# Task consensus: 9 of 34
# Accuracy Simulation: 0.2647058823529412
# ============================
# Hard Tasks: 4
# Easy Tasks: 32
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 17
# Workers Trained: 45
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.84
# Selected Best Workers: 13
# Tasks already done 6 from the total of 35
# Task consensus: 12 of 35
# Accuracy Simulation: 0.34285714285714286
# ============================
# Hard Tasks: 4
# Easy Tasks: 32
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 18
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 11
# Tasks already done 4 from the total of 36
# Task consensus: 13 of 36
# Accuracy Simulation: 0.3611111111111111
# ============================
# Hard Tasks: 4
# Easy Tasks: 33
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 18
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 8
# Tasks already done 4 from the total of 37
# Task consensus: 11 of 37
# Accuracy Simulation: 0.2972972972972973
# ============================
# Hard Tasks: 4
# Easy Tasks: 34
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 19
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.845
# Selected Best Workers: 11
# Tasks already done 4 from the total of 38
# Task consensus: 12 of 38
# Accuracy Simulation: 0.3157894736842105
# ============================
# Hard Tasks: 4
# Easy Tasks: 35
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 19
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 9
# Tasks already done 3 from the total of 39
# Task consensus: 13 of 39
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 4
# Easy Tasks: 36
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 20
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 7
# Tasks already done 2 from the total of 40
# Task consensus: 14 of 40
# Accuracy Simulation: 0.35
# ============================
# Hard Tasks: 4
# Easy Tasks: 37
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 20
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 11
# Tasks already done 4 from the total of 41
# Task consensus: 12 of 41
# Accuracy Simulation: 0.2926829268292683
# ============================
# Hard Tasks: 4
# Easy Tasks: 38
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 21
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 6
# Tasks already done 1 from the total of 42
# Hard Tasks: 4
# Easy Tasks: 39
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 21
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 9 from the total of 43
# Task consensus: 18 of 43
# Accuracy Simulation: 0.4186046511627907
# ============================
# Hard Tasks: 4
# Easy Tasks: 40
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 22
# Workers Trained: 47
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.82
# Selected Best Workers: 15
# Tasks already done 5 from the total of 44
# Task consensus: 14 of 44
# Accuracy Simulation: 0.3181818181818182
# ============================
# Hard Tasks: 4
# Easy Tasks: 40
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 22
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.89
# Selected Best Workers: 8
# Tasks already done 4 from the total of 45
# Task consensus: 16 of 45
# Accuracy Simulation: 0.35555555555555557
# ============================
# Hard Tasks: 5
# Easy Tasks: 41
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 23
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 6 from the total of 46
# Task consensus: 16 of 46
# Accuracy Simulation: 0.34782608695652173
# ============================
# Hard Tasks: 5
# Easy Tasks: 42
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 23
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 14
# Tasks already done 6 from the total of 47
# Task consensus: 14 of 47
# Accuracy Simulation: 0.2978723404255319
# ============================
# Hard Tasks: 5
# Easy Tasks: 43
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 24
# Workers Trained: 48
# Cutoff for Performance: 0.205
# Cutoff for Probability: 0.88
# Selected Best Workers: 12
# Tasks already done 8 from the total of 48
# Task consensus: 19 of 48
# Accuracy Simulation: 0.3958333333333333
# ============================
# Hard Tasks: 5
# Easy Tasks: 44
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 24
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 10
# Tasks already done 3 from the total of 49
# Task consensus: 5 of 49
# Accuracy Simulation: 0.10204081632653061
# ============================
# Hard Tasks: 5
# Easy Tasks: 45
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 25
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.81
# Selected Best Workers: 14
# Tasks already done 8 from the total of 50
# Task consensus: 15 of 50
# Accuracy Simulation: 0.3
# ============================
# Hard Tasks: 5
# Easy Tasks: 46
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 25
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.87
# Selected Best Workers: 13
# Tasks already done 6 from the total of 51
# Task consensus: 19 of 51
# Accuracy Simulation: 0.37254901960784315
# ============================
# Hard Tasks: 5
# Easy Tasks: 47
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 26
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 10
# Tasks already done 5 from the total of 52
# Task consensus: 17 of 52
# Accuracy Simulation: 0.3269230769230769
# ============================
# Hard Tasks: 5
# Easy Tasks: 48
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 26
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 12
# Tasks already done 5 from the total of 53
# Task consensus: 15 of 53
# Accuracy Simulation: 0.2830188679245283
# ============================
# Hard Tasks: 5
# Easy Tasks: 49
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 27
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 8
# Tasks already done 4 from the total of 54
# Task consensus: 18 of 54
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 6
# Easy Tasks: 50
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 27
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 15
# Tasks already done 5 from the total of 55
# Task consensus: 8 of 55
# Accuracy Simulation: 0.14545454545454545
# ============================
# Hard Tasks: 6
# Easy Tasks: 50
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 28
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 11
# Tasks already done 6 from the total of 56
# Task consensus: 11 of 56
# Accuracy Simulation: 0.19642857142857142
# ============================
# Hard Tasks: 6
# Easy Tasks: 51
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 28
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 19
# Tasks already done 7 from the total of 57
# Task consensus: 15 of 57
# Accuracy Simulation: 0.2631578947368421
# ============================
# Hard Tasks: 6
# Easy Tasks: 52
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 29
# Workers Trained: 48
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.83
# Selected Best Workers: 13
# Tasks already done 7 from the total of 58
# Task consensus: 22 of 58
# Accuracy Simulation: 0.3793103448275862
# ============================
# Hard Tasks: 6
# Easy Tasks: 53
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 29
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.82
# Selected Best Workers: 13
# Tasks already done 6 from the total of 59
# Task consensus: 17 of 59
# Accuracy Simulation: 0.288135593220339
# ============================
# Hard Tasks: 6
# Easy Tasks: 54
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 30
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 7 from the total of 60
# Task consensus: 18 of 60
# Accuracy Simulation: 0.3
# ============================
# Hard Tasks: 6
# Easy Tasks: 55
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 30
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 9
# Tasks already done 2 from the total of 61
# Task consensus: 16 of 61
# Accuracy Simulation: 0.26229508196721313
# ============================
# Hard Tasks: 6
# Easy Tasks: 56
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 31
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.875
# Selected Best Workers: 12
# Tasks already done 7 from the total of 62
# Task consensus: 17 of 62
# Accuracy Simulation: 0.27419354838709675
# ============================
# Hard Tasks: 6
# Easy Tasks: 57
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 31
# Workers Trained: 49
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.84
# Selected Best Workers: 13
# Tasks already done 6 from the total of 63
# Task consensus: 15 of 63
# Accuracy Simulation: 0.23809523809523808
# ============================
# Hard Tasks: 6
# Easy Tasks: 58
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 32
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 19
# Tasks already done 10 from the total of 64
# Task consensus: 27 of 64
# Accuracy Simulation: 0.421875
# ============================
# Hard Tasks: 6
# Easy Tasks: 58
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 32
# Workers Trained: 50
# Cutoff for Performance: 0.087
# Cutoff for Probability: 0.85
# Selected Best Workers: 15
# Tasks already done 9 from the total of 65
# Task consensus: 25 of 65
# Accuracy Simulation: 0.38461538461538464
# ============================
# Hard Tasks: 7
# Easy Tasks: 59
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 33
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.875
# Selected Best Workers: 18
# Tasks already done 7 from the total of 66
# Task consensus: 20 of 66
# Accuracy Simulation: 0.30303030303030304
# ============================
# Hard Tasks: 7
# Easy Tasks: 60
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 33
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.82
# Selected Best Workers: 15
# Tasks already done 8 from the total of 67
# Task consensus: 15 of 67
# Accuracy Simulation: 0.22388059701492538
# ============================
# Hard Tasks: 7
# Easy Tasks: 61
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 34
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.84
# Selected Best Workers: 17
# Tasks already done 9 from the total of 68
# Task consensus: 27 of 68
# Accuracy Simulation: 0.39705882352941174
# ============================
# Hard Tasks: 7
# Easy Tasks: 62
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 34
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 7 from the total of 69
# Task consensus: 23 of 69
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 7
# Easy Tasks: 63
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 35
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 16
# Tasks already done 7 from the total of 70
# Task consensus: 15 of 70
# Accuracy Simulation: 0.21428571428571427
# ============================
# Hard Tasks: 7
# Easy Tasks: 64
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 35
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 13
# Tasks already done 5 from the total of 71
# Task consensus: 21 of 71
# Accuracy Simulation: 0.29577464788732394
# ============================
# Hard Tasks: 7
# Easy Tasks: 65
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 36
# Workers Trained: 50
# Cutoff for Performance: 0.25
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 13 from the total of 72
# Task consensus: 26 of 72
# Accuracy Simulation: 0.3611111111111111
# ============================
# Hard Tasks: 7
# Easy Tasks: 66
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 36
# Workers Trained: 50
# Cutoff for Performance: 0.078
# Cutoff for Probability: 0.87
# Selected Best Workers: 15
# Tasks already done 7 from the total of 73
# Task consensus: 22 of 73
# Accuracy Simulation: 0.3013698630136986
# ============================
# Hard Tasks: 7
# Easy Tasks: 67
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 37
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.835
# Selected Best Workers: 14
# Tasks already done 4 from the total of 74
# Task consensus: 18 of 74
# Accuracy Simulation: 0.24324324324324326
# ============================
# Hard Tasks: 8
# Easy Tasks: 68
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 37
# Workers Trained: 50
# Cutoff for Performance: 0.078
# Cutoff for Probability: 0.845
# Selected Best Workers: 18
# Tasks already done 10 from the total of 75
# Task consensus: 23 of 75
# Accuracy Simulation: 0.30666666666666664
# ============================
# Hard Tasks: 8
# Easy Tasks: 68
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 38
# Workers Trained: 48
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 7 from the total of 76
# Task consensus: 18 of 76
# Accuracy Simulation: 0.23684210526315788
# ============================
# Hard Tasks: 8
# Easy Tasks: 69
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 38
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 12
# Tasks already done 5 from the total of 77
# Task consensus: 20 of 77
# Accuracy Simulation: 0.2597402597402597
# ============================
# Hard Tasks: 8
# Easy Tasks: 70
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 39
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 14
# Tasks already done 4 from the total of 78
# Task consensus: 17 of 78
# Accuracy Simulation: 0.21794871794871795
# ============================
# Hard Tasks: 8
# Easy Tasks: 71
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 39
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 15
# Tasks already done 5 from the total of 79
# Task consensus: 22 of 79
# Accuracy Simulation: 0.27848101265822783
# ============================
# Hard Tasks: 8
# Easy Tasks: 72
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 40
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 9 from the total of 80
# Task consensus: 33 of 80
# Accuracy Simulation: 0.4125
# ============================
# Hard Tasks: 8
# Easy Tasks: 73
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 40
# Workers Trained: 49
# Cutoff for Performance: 0.04
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 8 from the total of 81
# Task consensus: 18 of 81
# Accuracy Simulation: 0.2222222222222222
# ============================
# Hard Tasks: 8
# Easy Tasks: 74
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 41
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 16
# Tasks already done 6 from the total of 82
# Task consensus: 17 of 82
# Accuracy Simulation: 0.2073170731707317
# ============================
# Hard Tasks: 8
# Easy Tasks: 75
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 41
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 16
# Tasks already done 5 from the total of 83
# Task consensus: 26 of 83
# Accuracy Simulation: 0.3132530120481928
# ============================
# Hard Tasks: 8
# Easy Tasks: 76
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 42
# Workers Trained: 50
# Cutoff for Performance: 0.16
# Cutoff for Probability: 0.85
# Selected Best Workers: 19
# Tasks already done 11 from the total of 84
# Task consensus: 30 of 84
# Accuracy Simulation: 0.35714285714285715
# ============================
# Hard Tasks: 8
# Easy Tasks: 76
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 42
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 5 from the total of 85
# Task consensus: 21 of 85
# Accuracy Simulation: 0.24705882352941178
# ============================
# Hard Tasks: 9
# Easy Tasks: 77
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 43
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.855
# Selected Best Workers: 15
# Tasks already done 7 from the total of 86
# Task consensus: 23 of 86
# Accuracy Simulation: 0.26744186046511625
# ============================
# Hard Tasks: 9
# Easy Tasks: 78
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 43
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.865
# Selected Best Workers: 13
# Tasks already done 7 from the total of 87
# Task consensus: 29 of 87
# Accuracy Simulation: 0.3333333333333333
# ============================
# Hard Tasks: 9
# Easy Tasks: 79
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 44
# Workers Trained: 50
# Cutoff for Performance: 0.235
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 15 from the total of 88
# Task consensus: 23 of 88
# Accuracy Simulation: 0.26136363636363635
# ============================
# Hard Tasks: 9
# Easy Tasks: 80
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 44
# Workers Trained: 50
# Cutoff for Performance: 0.07
# Cutoff for Probability: 0.835
# Selected Best Workers: 20
# Tasks already done 8 from the total of 89
# Task consensus: 27 of 89
# Accuracy Simulation: 0.30337078651685395
# ============================
# Hard Tasks: 9
# Easy Tasks: 81
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 45
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.865
# Selected Best Workers: 18
# Tasks already done 10 from the total of 90
# Task consensus: 26 of 90
# Accuracy Simulation: 0.28888888888888886
# ============================
# Hard Tasks: 9
# Easy Tasks: 82
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 45
# Workers Trained: 50
# Cutoff for Performance: 0.058
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 9 from the total of 91
# Task consensus: 24 of 91
# Accuracy Simulation: 0.26373626373626374
# ============================
# Hard Tasks: 9
# Easy Tasks: 83
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 46
# Workers Trained: 50
# Cutoff for Performance: 0.16
# Cutoff for Probability: 0.87
# Selected Best Workers: 14
# Tasks already done 13 from the total of 92
# Task consensus: 36 of 92
# Accuracy Simulation: 0.391304347826087
# ============================
# Hard Tasks: 9
# Easy Tasks: 84
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 46
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.83
# Selected Best Workers: 17
# Tasks already done 7 from the total of 93
# Task consensus: 28 of 93
# Accuracy Simulation: 0.3010752688172043
# ============================
# Hard Tasks: 9
# Easy Tasks: 85
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 47
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.865
# Selected Best Workers: 18
# Tasks already done 12 from the total of 94
# Task consensus: 31 of 94
# Accuracy Simulation: 0.32978723404255317
# ============================
# Hard Tasks: 10
# Easy Tasks: 86
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 47
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.82
# Selected Best Workers: 14
# Tasks already done 6 from the total of 95
# Task consensus: 30 of 95
# Accuracy Simulation: 0.3157894736842105
# ============================
# Hard Tasks: 10
# Easy Tasks: 86
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 48
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.885
# Selected Best Workers: 17
# Tasks already done 7 from the total of 96
# Task consensus: 23 of 96
# Accuracy Simulation: 0.23958333333333334
# ============================
# Hard Tasks: 10
# Easy Tasks: 87
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 48
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 8 from the total of 97
# Task consensus: 29 of 97
# Accuracy Simulation: 0.29896907216494845
# ============================
# Hard Tasks: 10
# Easy Tasks: 88
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 49
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.86
# Selected Best Workers: 13
# Tasks already done 11 from the total of 98
# Task consensus: 25 of 98
# Accuracy Simulation: 0.25510204081632654
# ============================
# Hard Tasks: 10
# Easy Tasks: 89
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 49
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.86
# Selected Best Workers: 14
# Tasks already done 14 from the total of 99
# Task consensus: 32 of 99
# Accuracy Simulation: 0.32323232323232326
# ============================
# Hard Tasks: 10
# Easy Tasks: 90
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 50
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 10 from the total of 100
# Task consensus: 29 of 100
# Accuracy Simulation: 0.29
# ============================
# Hard Tasks: 10
# Easy Tasks: 91
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 50
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.83
# Selected Best Workers: 15
# Tasks already done 11 from the total of 101
# Task consensus: 33 of 101
# Accuracy Simulation: 0.32673267326732675
# ============================
# Hard Tasks: 10
# Easy Tasks: 92
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 51
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 7 from the total of 102
# Task consensus: 32 of 102
# Accuracy Simulation: 0.3137254901960784
# ============================
# Hard Tasks: 10
# Easy Tasks: 93
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 51
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 12 from the total of 103
# Task consensus: 25 of 103
# Accuracy Simulation: 0.24271844660194175
# ============================
# Hard Tasks: 10
# Easy Tasks: 94
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 52
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.85
# Selected Best Workers: 12
# Tasks already done 13 from the total of 104
# Task consensus: 38 of 104
# Accuracy Simulation: 0.36538461538461536
# ============================
# Hard Tasks: 10
# Easy Tasks: 94
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 52
# Workers Trained: 50
# Cutoff for Performance: 0.095
# Cutoff for Probability: 0.865
# Selected Best Workers: 17
# Tasks already done 7 from the total of 105
# Task consensus: 29 of 105
# Accuracy Simulation: 0.2761904761904762
# ============================
# Hard Tasks: 11
# Easy Tasks: 95
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 53
# Workers Trained: 50
# Cutoff for Performance: 0.083
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 7 from the total of 106
# Task consensus: 32 of 106
# Accuracy Simulation: 0.3018867924528302
# ============================
# Hard Tasks: 11
# Easy Tasks: 96
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 53
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.855
# Selected Best Workers: 18
# Tasks already done 10 from the total of 107
# Task consensus: 28 of 107
# Accuracy Simulation: 0.2616822429906542
# ============================
# Hard Tasks: 11
# Easy Tasks: 97
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 54
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.87
# Selected Best Workers: 19
# Tasks already done 8 from the total of 108
# Task consensus: 29 of 108
# Accuracy Simulation: 0.26851851851851855
# ============================
# Hard Tasks: 11
# Easy Tasks: 98
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 54
# Workers Trained: 50
# Cutoff for Performance: 0.064
# Cutoff for Probability: 0.865
# Selected Best Workers: 19
# Tasks already done 8 from the total of 109
# Task consensus: 33 of 109
# Accuracy Simulation: 0.30275229357798167
# ============================
# Hard Tasks: 11
# Easy Tasks: 99
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 55
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 13 from the total of 110
# Task consensus: 23 of 110
# Accuracy Simulation: 0.20909090909090908
# ============================
# Hard Tasks: 11
# Easy Tasks: 100
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 55
# Workers Trained: 50
# Cutoff for Performance: 0.095
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 9 from the total of 111
# Task consensus: 38 of 111
# Accuracy Simulation: 0.34234234234234234
# ============================
# Hard Tasks: 11
# Easy Tasks: 101
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 56
# Workers Trained: 50
# Cutoff for Performance: 0.19
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 16 from the total of 112
# Task consensus: 31 of 112
# Accuracy Simulation: 0.2767857142857143
# ============================
# Hard Tasks: 11
# Easy Tasks: 102
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 56
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.88
# Selected Best Workers: 15
# Tasks already done 14 from the total of 113
# Task consensus: 26 of 113
# Accuracy Simulation: 0.23008849557522124
# ============================
# Hard Tasks: 11
# Easy Tasks: 103
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 57
# Workers Trained: 50
# Cutoff for Performance: 0.222
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 18 from the total of 114
# Task consensus: 33 of 114
# Accuracy Simulation: 0.2894736842105263
# ============================
# Hard Tasks: 12
# Easy Tasks: 104
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 57
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.865
# Selected Best Workers: 17
# Tasks already done 9 from the total of 115
# Task consensus: 36 of 115
# Accuracy Simulation: 0.3130434782608696
# ============================
# Hard Tasks: 12
# Easy Tasks: 104
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 58
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.85
# Selected Best Workers: 19
# Tasks already done 11 from the total of 116
# Task consensus: 29 of 116
# Accuracy Simulation: 0.25
# ============================
# Hard Tasks: 12
# Easy Tasks: 105
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 58
# Workers Trained: 50
# Cutoff for Performance: 0.19
# Cutoff for Probability: 0.885
# Selected Best Workers: 17
# Tasks already done 14 from the total of 117
# Task consensus: 31 of 117
# Accuracy Simulation: 0.26495726495726496
# ============================
# Hard Tasks: 12
# Easy Tasks: 106
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 59
# Workers Trained: 50
# Cutoff for Performance: 0.137
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 14 from the total of 118
# Task consensus: 33 of 118
# Accuracy Simulation: 0.2796610169491525
# ============================
# Hard Tasks: 12
# Easy Tasks: 107
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 59
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.83
# Selected Best Workers: 13
# Tasks already done 16 from the total of 119
# Task consensus: 46 of 119
# Accuracy Simulation: 0.3865546218487395
# ============================
# Hard Tasks: 12
# Easy Tasks: 108
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 60
# Workers Trained: 50
# Cutoff for Performance: 0.095
# Cutoff for Probability: 0.87
# Selected Best Workers: 19
# Tasks already done 10 from the total of 120
# Task consensus: 32 of 120
# Accuracy Simulation: 0.26666666666666666
# ============================
# Hard Tasks: 12
# Easy Tasks: 109
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 60
# Workers Trained: 50
# Cutoff for Performance: 0.16
# Cutoff for Probability: 0.865
# Selected Best Workers: 17
# Tasks already done 15 from the total of 121
# Task consensus: 43 of 121
# Accuracy Simulation: 0.35537190082644626
# ============================
# Hard Tasks: 12
# Easy Tasks: 110
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 61
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.905
# Selected Best Workers: 17
# Tasks already done 13 from the total of 122
# Task consensus: 26 of 122
# Accuracy Simulation: 0.21311475409836064
# ============================
# Hard Tasks: 12
# Easy Tasks: 111
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 61
# Workers Trained: 50
# Cutoff for Performance: 0.182
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 16 from the total of 123
# Task consensus: 33 of 123
# Accuracy Simulation: 0.2682926829268293
# ============================
# Hard Tasks: 12
# Easy Tasks: 112
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 62
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 12 from the total of 124
# Task consensus: 35 of 124
# Accuracy Simulation: 0.28225806451612906
# ============================
# Hard Tasks: 12
# Easy Tasks: 112
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 62
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.88
# Selected Best Workers: 17
# Tasks already done 12 from the total of 125
# Task consensus: 24 of 125
# Accuracy Simulation: 0.192
# ============================
# Hard Tasks: 13
# Easy Tasks: 113
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 63
# Workers Trained: 50
# Cutoff for Performance: 0.058
# Cutoff for Probability: 0.82
# Selected Best Workers: 18
# Tasks already done 9 from the total of 126
# Task consensus: 24 of 126
# Accuracy Simulation: 0.19047619047619047
# ============================
# Hard Tasks: 13
# Easy Tasks: 114
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 63
# Workers Trained: 50
# Cutoff for Performance: 0.177
# Cutoff for Probability: 0.875
# Selected Best Workers: 18
# Tasks already done 15 from the total of 127
# Task consensus: 27 of 127
# Accuracy Simulation: 0.2125984251968504
# ============================
# Hard Tasks: 13
# Easy Tasks: 115
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 64
# Workers Trained: 50
# Cutoff for Performance: 0.196
# Cutoff for Probability: 0.845
# Selected Best Workers: 16
# Tasks already done 17 from the total of 128
# Task consensus: 44 of 128
# Accuracy Simulation: 0.34375
# ============================
# Hard Tasks: 13
# Easy Tasks: 116
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 64
# Workers Trained: 50
# Cutoff for Performance: 0.21
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 18 from the total of 129
# Task consensus: 41 of 129
# Accuracy Simulation: 0.3178294573643411
# ============================
# Hard Tasks: 13
# Easy Tasks: 117
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 65
# Workers Trained: 50
# Cutoff for Performance: 0.131
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 13 from the total of 130
# Task consensus: 37 of 130
# Accuracy Simulation: 0.2846153846153846
# ============================
# Hard Tasks: 13
# Easy Tasks: 118
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 65
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 9 from the total of 131
# Task consensus: 35 of 131
# Accuracy Simulation: 0.26717557251908397
# ============================
# Hard Tasks: 13
# Easy Tasks: 119
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 66
# Workers Trained: 50
# Cutoff for Performance: 0.195
# Cutoff for Probability: 0.85
# Selected Best Workers: 19
# Tasks already done 18 from the total of 132
# Task consensus: 45 of 132
# Accuracy Simulation: 0.3409090909090909
# ============================
# Hard Tasks: 13
# Easy Tasks: 120
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 66
# Workers Trained: 50
# Cutoff for Performance: 0.163
# Cutoff for Probability: 0.855
# Selected Best Workers: 17
# Tasks already done 14 from the total of 133
# Task consensus: 42 of 133
# Accuracy Simulation: 0.3157894736842105
# ============================
# Hard Tasks: 13
# Easy Tasks: 121
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 67
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.875
# Selected Best Workers: 19
# Tasks already done 13 from the total of 134
# Task consensus: 26 of 134
# Accuracy Simulation: 0.19402985074626866
# ============================
# Hard Tasks: 14
# Easy Tasks: 122
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 67
# Workers Trained: 50
# Cutoff for Performance: 0.131
# Cutoff for Probability: 0.855
# Selected Best Workers: 16
# Tasks already done 13 from the total of 135
# Task consensus: 36 of 135
# Accuracy Simulation: 0.26666666666666666
# ============================
# Hard Tasks: 14
# Easy Tasks: 122
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 68
# Workers Trained: 50
# Cutoff for Performance: 0.117
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 12 from the total of 136
# Task consensus: 42 of 136
# Accuracy Simulation: 0.3088235294117647
# ============================
# Hard Tasks: 14
# Easy Tasks: 123
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 68
# Workers Trained: 50
# Cutoff for Performance: 0.177
# Cutoff for Probability: 0.82
# Selected Best Workers: 16
# Tasks already done 19 from the total of 137
# Task consensus: 42 of 137
# Accuracy Simulation: 0.30656934306569344
# ============================
# Hard Tasks: 14
# Easy Tasks: 124
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 69
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.88
# Selected Best Workers: 16
# Tasks already done 14 from the total of 138
# Task consensus: 35 of 138
# Accuracy Simulation: 0.2536231884057971
# ============================
# Hard Tasks: 14
# Easy Tasks: 125
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 69
# Workers Trained: 50
# Cutoff for Performance: 0.108
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 12 from the total of 139
# Task consensus: 35 of 139
# Accuracy Simulation: 0.2517985611510791
# ============================
# Hard Tasks: 14
# Easy Tasks: 126
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 70
# Workers Trained: 50
# Cutoff for Performance: 0.125
# Cutoff for Probability: 0.89
# Selected Best Workers: 14
# Tasks already done 16 from the total of 140
# Task consensus: 32 of 140
# Accuracy Simulation: 0.22857142857142856
# ============================
# Hard Tasks: 14
# Easy Tasks: 127
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 70
# Workers Trained: 50
# Cutoff for Performance: 0.091
# Cutoff for Probability: 0.855
# Selected Best Workers: 14
# Tasks already done 11 from the total of 141
# Task consensus: 36 of 141
# Accuracy Simulation: 0.2553191489361702
# ============================
# Hard Tasks: 14
# Easy Tasks: 128
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 71
# Workers Trained: 50
# Cutoff for Performance: 0.091
# Cutoff for Probability: 0.875
# Selected Best Workers: 16
# Tasks already done 10 from the total of 142
# Task consensus: 38 of 142
# Accuracy Simulation: 0.2676056338028169
# ============================
# Hard Tasks: 14
# Easy Tasks: 129
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 71
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.865
# Selected Best Workers: 15
# Tasks already done 16 from the total of 143
# Task consensus: 44 of 143
# Accuracy Simulation: 0.3076923076923077
# ============================
# Hard Tasks: 14
# Easy Tasks: 130
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 72
# Workers Trained: 50
# Cutoff for Performance: 0.097
# Cutoff for Probability: 0.85
# Selected Best Workers: 16
# Tasks already done 10 from the total of 144
# Task consensus: 37 of 144
# Accuracy Simulation: 0.2569444444444444
# ============================
# Hard Tasks: 14
# Easy Tasks: 130
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 72
# Workers Trained: 50
# Cutoff for Performance: 0.157
# Cutoff for Probability: 0.865
# Selected Best Workers: 18
# Tasks already done 15 from the total of 145
# Task consensus: 28 of 145
# Accuracy Simulation: 0.19310344827586207
# ============================
# Hard Tasks: 15
# Easy Tasks: 131
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 73
# Workers Trained: 50
# Cutoff for Performance: 0.137
# Cutoff for Probability: 0.855
# Selected Best Workers: 20
# Tasks already done 17 from the total of 146
# Task consensus: 47 of 146
# Accuracy Simulation: 0.3219178082191781
# ============================
# Hard Tasks: 15
# Easy Tasks: 132
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 73
# Workers Trained: 50
# Cutoff for Performance: 0.0
# Cutoff for Probability: 0.88
# Selected Best Workers: 15
# Tasks already done 9 from the total of 147
# Task consensus: 36 of 147
# Accuracy Simulation: 0.24489795918367346
# ============================
# Hard Tasks: 15
# Easy Tasks: 133
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 74
# Workers Trained: 50
# Cutoff for Performance: 0.121
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 12 from the total of 148
# Task consensus: 37 of 148
# Accuracy Simulation: 0.25
# ============================
# Hard Tasks: 15
# Easy Tasks: 134
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 74
# Workers Trained: 50
# Cutoff for Performance: 0.091
# Cutoff for Probability: 0.865
# Selected Best Workers: 16
# Tasks already done 10 from the total of 149
# Task consensus: 23 of 149
# Accuracy Simulation: 0.15436241610738255
# ============================
# Hard Tasks: 15
# Easy Tasks: 135
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 75
# Workers Trained: 50
# Cutoff for Performance: 0.1
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 11 from the total of 150
# Task consensus: 42 of 150
# Accuracy Simulation: 0.28
# ============================
# Hard Tasks: 15
# Easy Tasks: 136
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 75
# Workers Trained: 50
# Cutoff for Performance: 0.195
# Cutoff for Probability: 0.815
# Selected Best Workers: 15
# Tasks already done 23 from the total of 151
# Task consensus: 59 of 151
# Accuracy Simulation: 0.39072847682119205
# ============================
# Hard Tasks: 15
# Easy Tasks: 137
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 76
# Workers Trained: 50
# Cutoff for Performance: 0.089
# Cutoff for Probability: 0.825
# Selected Best Workers: 15
# Tasks already done 9 from the total of 152
# Task consensus: 40 of 152
# Accuracy Simulation: 0.2631578947368421
# ============================
# Hard Tasks: 15
# Easy Tasks: 138
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 76
# Workers Trained: 50
# Cutoff for Performance: 0.137
# Cutoff for Probability: 0.86
# Selected Best Workers: 20
# Tasks already done 15 from the total of 153
# Task consensus: 53 of 153
# Accuracy Simulation: 0.3464052287581699
# ============================
# Hard Tasks: 15
# Easy Tasks: 139
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 77
# ...
# Workers Trained: 50
# Cutoff for Performance: 0.172
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 25 from the total of 226
# Task consensus: 76 of 226
# Accuracy Simulation: 0.336283185840708
# ============================
# Hard Tasks: 23
# Easy Tasks: 204
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 113
# Workers Trained: 50
# Cutoff for Performance: 0.21
# Cutoff for Probability: 0.85
# Selected Best Workers: 19
# Tasks already done 30 from the total of 227
# Task consensus: 71 of 227
# Accuracy Simulation: 0.31277533039647576
# ============================
# Hard Tasks: 23
# Easy Tasks: 205
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 114
# Workers Trained: 50
# Cutoff for Performance: 0.154
# Cutoff for Probability: 0.845
# Selected Best Workers: 16
# Tasks already done 25 from the total of 228
# Task consensus: 66 of 228
# Accuracy Simulation: 0.2894736842105263
# ============================
# Hard Tasks: 23
# Easy Tasks: 206
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 114
# Workers Trained: 50
# Cutoff for Performance: 0.182
# Cutoff for Probability: 0.845
# Selected Best Workers: 15
# Tasks already done 28 from the total of 229
# Task consensus: 65 of 229
# Accuracy Simulation: 0.2838427947598253
# ============================
# Hard Tasks: 23
# Easy Tasks: 207
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 115
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.83
# Selected Best Workers: 13
# Tasks already done 31 from the total of 230
# Task consensus: 62 of 230
# Accuracy Simulation: 0.26956521739130435
# ============================
# Hard Tasks: 23
# Easy Tasks: 208
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 115
# Workers Trained: 50
# Cutoff for Performance: 0.118
# Cutoff for Probability: 0.84
# Selected Best Workers: 16
# Tasks already done 19 from the total of 231
# Task consensus: 43 of 231
# Accuracy Simulation: 0.18614718614718614
# ============================
# Hard Tasks: 23
# Easy Tasks: 209
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 116
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.88
# Selected Best Workers: 17
# Tasks already done 23 from the total of 232
# Task consensus: 76 of 232
# Accuracy Simulation: 0.3275862068965517
# ============================
# Hard Tasks: 23
# Easy Tasks: 210
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 116
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.86
# Selected Best Workers: 18
# Tasks already done 24 from the total of 233
# Task consensus: 73 of 233
# Accuracy Simulation: 0.3133047210300429
# ============================
# Hard Tasks: 23
# Easy Tasks: 211
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 117
# Workers Trained: 50
# Cutoff for Performance: 0.104
# Cutoff for Probability: 0.865
# Selected Best Workers: 16
# Tasks already done 16 from the total of 234
# Task consensus: 61 of 234
# Accuracy Simulation: 0.2606837606837607
# ============================
# Hard Tasks: 24
# Easy Tasks: 212
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 117
# Workers Trained: 50
# Cutoff for Performance: 0.226
# Cutoff for Probability: 0.85
# Selected Best Workers: 19
# Tasks already done 32 from the total of 235
# Task consensus: 80 of 235
# Accuracy Simulation: 0.3404255319148936
# ============================
# Hard Tasks: 24
# Easy Tasks: 212
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 118
# Workers Trained: 50
# Cutoff for Performance: 0.131
# Cutoff for Probability: 0.88
# Selected Best Workers: 15
# Tasks already done 23 from the total of 236
# Task consensus: 70 of 236
# Accuracy Simulation: 0.2966101694915254
# ============================
# Hard Tasks: 24
# Easy Tasks: 213
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 118
# Workers Trained: 50
# Cutoff for Performance: 0.139
# Cutoff for Probability: 0.85
# Selected Best Workers: 18
# Tasks already done 22 from the total of 237
# Task consensus: 67 of 237
# Accuracy Simulation: 0.28270042194092826
# ============================
# Hard Tasks: 24
# Easy Tasks: 214
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 119
# Workers Trained: 50
# Cutoff for Performance: 0.197
# Cutoff for Probability: 0.89
# Selected Best Workers: 18
# Tasks already done 25 from the total of 238
# Task consensus: 79 of 238
# Accuracy Simulation: 0.33613445378151263
# ============================
# Hard Tasks: 24
# Easy Tasks: 215
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 119
# Workers Trained: 50
# Cutoff for Performance: 0.148
# Cutoff for Probability: 0.86
# Selected Best Workers: 17
# Tasks already done 23 from the total of 239
# Task consensus: 85 of 239
# Accuracy Simulation: 0.35564853556485354
# ============================
# Hard Tasks: 24
# Easy Tasks: 216
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 120
# Workers Trained: 50
# Cutoff for Performance: 0.14
# Cutoff for Probability: 0.845
# Selected Best Workers: 16
# Tasks already done 20 from the total of 240
# Task consensus: 64 of 240
# Accuracy Simulation: 0.26666666666666666
# ============================
# Hard Tasks: 24
# Easy Tasks: 217
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 120
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 23 from the total of 241
# Task consensus: 79 of 241
# Accuracy Simulation: 0.3278008298755187
# ============================
# Hard Tasks: 24
# Easy Tasks: 218
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 121
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 32 from the total of 242
# Task consensus: 58 of 242
# Accuracy Simulation: 0.2396694214876033
# ============================
# Hard Tasks: 24
# Easy Tasks: 219
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 121
# Workers Trained: 50
# Cutoff for Performance: 0.204
# Cutoff for Probability: 0.88
# Selected Best Workers: 18
# Tasks already done 31 from the total of 243
# Task consensus: 78 of 243
# Accuracy Simulation: 0.32098765432098764
# ============================
# Hard Tasks: 24
# Easy Tasks: 220
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 122
# Workers Trained: 50
# Cutoff for Performance: 0.15
# Cutoff for Probability: 0.84
# Selected Best Workers: 15
# Tasks already done 22 from the total of 244
# Task consensus: 63 of 244
# Accuracy Simulation: 0.2581967213114754
# ============================
# Hard Tasks: 24
# Easy Tasks: 220
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 122
# Workers Trained: 50
# Cutoff for Performance: 0.164
# Cutoff for Probability: 0.855
# Selected Best Workers: 16
# Tasks already done 23 from the total of 245
# Task consensus: 71 of 245
# Accuracy Simulation: 0.2897959183673469
# ============================
# Hard Tasks: 25
# Easy Tasks: 221
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 123
# Workers Trained: 50
# Cutoff for Performance: 0.153
# Cutoff for Probability: 0.87
# Selected Best Workers: 18
# Tasks already done 25 from the total of 246
# Task consensus: 48 of 246
# Accuracy Simulation: 0.1951219512195122
# ============================
# Hard Tasks: 25
# Easy Tasks: 222
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 123
# Workers Trained: 50
# Cutoff for Performance: 0.135
# Cutoff for Probability: 0.83
# Selected Best Workers: 18
# Tasks already done 22 from the total of 247
# Task consensus: 78 of 247
# Accuracy Simulation: 0.3157894736842105
# ============================
# Hard Tasks: 25
# Easy Tasks: 223
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 124
# Workers Trained: 50
# Cutoff for Performance: 0.172
# Cutoff for Probability: 0.88
# Selected Best Workers: 17
# Tasks already done 28 from the total of 248
# Task consensus: 63 of 248
# Accuracy Simulation: 0.2540322580645161
# ============================
# Hard Tasks: 25
# Easy Tasks: 224
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 124
# Workers Trained: 50
# Cutoff for Performance: 0.154
# Cutoff for Probability: 0.85
# Selected Best Workers: 17
# Tasks already done 23 from the total of 249
# Task consensus: 45 of 249
# Accuracy Simulation: 0.18072289156626506
# ============================
# Hard Tasks: 25
# Easy Tasks: 225
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 125
# Workers Trained: 50
# Cutoff for Performance: 0.167
# Cutoff for Probability: 0.855
# Selected Best Workers: 16
# Tasks already done 24 from the total of 250
# Task consensus: 78 of 250
# Accuracy Simulation: 0.312
# ============================
# Hard Tasks: 25
# Easy Tasks: 226
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 125
# Workers Trained: 50
# Cutoff for Performance: 0.131
# Cutoff for Probability: 0.87
# Selected Best Workers: 16
# Tasks already done 23 from the total of 251
# Task consensus: 58 of 251
# Accuracy Simulation: 0.23107569721115537
# ============================
# Hard Tasks: 25
# Easy Tasks: 227
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 126
# Workers Trained: 50
# Cutoff for Performance: 0.188
# Cutoff for Probability: 0.845
# Selected Best Workers: 13
# Tasks already done 25 from the total of 252
# Task consensus: 76 of 252
# Accuracy Simulation: 0.30158730158730157
# ============================
# Hard Tasks: 25
# Easy Tasks: 228
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 126
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.825
# Selected Best Workers: 17
# Tasks already done 26 from the total of 253
# Task consensus: 74 of 253
# Accuracy Simulation: 0.2924901185770751
# ============================
# Hard Tasks: 25
# Easy Tasks: 229
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 127
# Workers Trained: 50
# Cutoff for Performance: 0.153
# Cutoff for Probability: 0.845
# Selected Best Workers: 19
# Tasks already done 25 from the total of 254
# Task consensus: 66 of 254
# Accuracy Simulation: 0.25984251968503935
# ============================
# Hard Tasks: 26
# Easy Tasks: 230
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 127
# Workers Trained: 50
# Cutoff for Performance: 0.136
# Cutoff for Probability: 0.845
# Selected Best Workers: 18
# Tasks already done 27 from the total of 255
# Task consensus: 53 of 255
# Accuracy Simulation: 0.20784313725490197
# ============================
# Hard Tasks: 26
# Easy Tasks: 230
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 128
# Workers Trained: 50
# Cutoff for Performance: 0.117
# Cutoff for Probability: 0.86
# Selected Best Workers: 18
# Tasks already done 18 from the total of 256
# Task consensus: 46 of 256
# Accuracy Simulation: 0.1796875
# ============================
# Hard Tasks: 26
# Easy Tasks: 231
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 128
# Workers Trained: 50
# Cutoff for Performance: 0.21
# Cutoff for Probability: 0.865
# Selected Best Workers: 20
# Tasks already done 37 from the total of 257
# Task consensus: 83 of 257
# Accuracy Simulation: 0.3229571984435798
# ============================
# Hard Tasks: 26
# Easy Tasks: 232
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 129
# Workers Trained: 50
# Cutoff for Performance: 0.18
# Cutoff for Probability: 0.885
# Selected Best Workers: 18
# Tasks already done 29 from the total of 258
# Task consensus: 60 of 258
# Accuracy Simulation: 0.23255813953488372
# ============================
# Hard Tasks: 26
# Easy Tasks: 233
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 129
# Workers Trained: 50
# Cutoff for Performance: 0.164
# Cutoff for Probability: 0.87
# Selected Best Workers: 20
# Tasks already done 30 from the total of 259
# Task consensus: 80 of 259
# Accuracy Simulation: 0.3088803088803089
# ============================
# Hard Tasks: 26
# Easy Tasks: 234
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 130
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.87
# Selected Best Workers: 11
# Tasks already done 34 from the total of 260
# Task consensus: 88 of 260
# Accuracy Simulation: 0.3384615384615385
# ============================
# Hard Tasks: 26
# Easy Tasks: 235
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 130
# Workers Trained: 50
# Cutoff for Performance: 0.188
# Cutoff for Probability: 0.875
# Selected Best Workers: 18
# Tasks already done 28 from the total of 261
# Task consensus: 72 of 261
# Accuracy Simulation: 0.27586206896551724
# ============================
# Hard Tasks: 26
# Easy Tasks: 236
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 131
# Workers Trained: 50
# Cutoff for Performance: 0.141
# Cutoff for Probability: 0.845
# Selected Best Workers: 21
# Tasks already done 25 from the total of 262
# Task consensus: 68 of 262
# Accuracy Simulation: 0.2595419847328244
# ============================
# Hard Tasks: 26
# Easy Tasks: 237
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 131
# Workers Trained: 50
# Cutoff for Performance: 0.164
# Cutoff for Probability: 0.83
# Selected Best Workers: 16
# Tasks already done 29 from the total of 263
# Task consensus: 74 of 263
# Accuracy Simulation: 0.2813688212927757
# ============================
# Hard Tasks: 26
# Easy Tasks: 238
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 132
# Workers Trained: 50
# Cutoff for Performance: 0.111
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 22 from the total of 264
# Task consensus: 74 of 264
# Accuracy Simulation: 0.2803030303030303
# ============================
# Hard Tasks: 26
# Easy Tasks: 238
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 132
# Workers Trained: 50
# Cutoff for Performance: 0.2
# Cutoff for Probability: 0.86
# Selected Best Workers: 16
# Tasks already done 34 from the total of 265
# Task consensus: 90 of 265
# Accuracy Simulation: 0.33962264150943394
# ============================
# Hard Tasks: 27
# Easy Tasks: 239
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 133
# Workers Trained: 50
# Cutoff for Performance: 0.196
# Cutoff for Probability: 0.86
# Selected Best Workers: 19
# Tasks already done 33 from the total of 266
# Task consensus: 51 of 266
# Accuracy Simulation: 0.19172932330827067
# ============================
# Hard Tasks: 27
# Easy Tasks: 240
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 133
# Workers Trained: 50
# Cutoff for Performance: 0.143
# Cutoff for Probability: 0.86
# Selected Best Workers: 15
# Tasks already done 30 from the total of 267
# Task consensus: 94 of 267
# Accuracy Simulation: 0.352059925093633
# ============================
# Hard Tasks: 27
# Easy Tasks: 241
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 134
# Workers Trained: 50
# Cutoff for Performance: 0.132
# Cutoff for Probability: 0.86
# Selected Best Workers: 13
# Tasks already done 25 from the total of 268
# Task consensus: 77 of 268
# Accuracy Simulation: 0.2873134328358209
# ============================
# Hard Tasks: 27
# Easy Tasks: 242
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 134
# Workers Trained: 50
# Cutoff for Performance: 0.182
# Cutoff for Probability: 0.855
# Selected Best Workers: 18
# Tasks already done 32 from the total of 269
# Task consensus: 92 of 269
# Accuracy Simulation: 0.3420074349442379
# ============================
# Hard Tasks: 27
# Easy Tasks: 243
# Good Workers: 45
# Poor Workers: 5
# Tasks to train: 135
# Workers Trained: 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-99c8be263cac> in <module>()
#       1 #total_tasks
# ----> 2 df_simulations, timeElapsed = simulations_df(500, "total_tasks", 30)
#
# <ipython-input-20-585c9b1842b8> in simulations_df(max_value, variable, number_simulations)
#       3     simulations = []
#       4     for k in range(number_simulations):
# ----> 5         results = train_parameter(max_value)
#       6         simulations.append((k, results))
#       7
#
# <ipython-input-11-aea4f9133c0d> in train_parameter(max_value)
#       9                                              p_good_workers = 0.9, #(0,1)
#      10                                              p_train_tasks = 0.5, #(0,1)
# ---> 11                                              workers_per_task = 7))) #3,5,7,9,11,13,15
#      12         except Exception:
#      13             pass
#
# <ipython-input-2-a462a3234eeb> in workers_algorithm(total_tasks, total_workers, p_hard_tasks, p_good_workers, answers_key, p_train_tasks, workers_per_task)
#     135         for i in positions:
#     136             vec_probs = [(1-p)/(len(answers_key)-1)] * (len(answers_key)-1)
# --> 137             vec_probs.insert(i,p) #insert place, value
#     138         list_vect_probs.append(vec_probs)
#     139
#
# KeyboardInterrupt:

# %%
#df_simulations#.head()

# %%
 print('Process with 100 iterations and 0-100 range of % to train(hh:mm:ss.ms) {}'.format(timeElapsed1))

# %%
#pd.read_csv('df_simulations.csv', sep=',', encoding="utf-8")

# %%
df_simulations.head()

# %%
accu = df_simulations.groupby('variable').mean()
#df_simulations.groupby('workers').std()

# %%
accu.sort_values('accuracy', ascending=False).head(10)['accuracy']

# %%
plt.figure(figsize=[16, 10])
plt.scatter(accu.index, accu['accuracy'])
plt.plot(accu.index, accu['accuracy'])
